# %% [markdown]
# Retrieve raw PDB files

# %%
from Bio.PDB.PDBList import PDBList
import os

# Initialize PDBList
pdbl = PDBList()

# Directory where the PDB files will be saved
pdb_directory = '/Users/javierherranzdelcerro/Desktop/PYT_SBI/SBPYT_project/raw_pdb'
if not os.path.exists(pdb_directory):
    os.makedirs(pdb_directory)

# Path to your pocket PDB files
pocket_pdb_directory = '/Users/javierherranzdelcerro/Desktop/PYT_SBI/SBPYT_project/dataset/pocket_pdb'

# List to hold the formatted PDB names
pdb_names = []

# Loop through each file in the directory
for filename in os.listdir(pocket_pdb_directory):
    if filename.endswith("_pocket.pdb"):
        # Extract the PDB identifier from the filename
        pdb_id = filename.split("_pocket.pdb")[0]
        
        # Append the formatted name to the list
        pdb_names.append(pdb_id.upper())  # PDB IDs are typically uppercase

for pdb_id in pdb_names:
    # Retrieve PDB file
    pdbl.retrieve_pdb_file(pdb_id, pdir=pdb_directory, file_format='pdb')

    print(f"Downloaded: {pdb_id}")
# Out:
# Downloading PDB structure '5l9g'...
# Downloaded: 5L9G
# Downloading PDB structure '1h46'...
# Downloaded: 1H46
# Downloading PDB structure '2py4'...
# Downloaded: 2PY4
# Downloading PDB structure '4jal'...
# Downloaded: 4JAL
# Downloading PDB structure '1nw7'...
# Downloaded: 1NW7
# Downloading PDB structure '2p7g'...
# Downloaded: 2P7G
# Downloading PDB structure '3qin'...
# Downloaded: 3QIN
# Downloading PDB structure '3gkz'...
# Downloaded: 3GKZ
# Downloading PDB structure '1zz1'...
# Downloaded: 1ZZ1
# Downloading PDB structure '1drk'...
# Downloaded: 1DRK
# Downloading PDB structure '5hvs'...
# Downloaded: 5HVS
# Downloading PDB structure '2v92'...
# Downloaded: 2V92
# Downloading PDB structure '1fkj'...
# Downloaded: 1FKJ
# Downloading PDB structure '4dew'...
# Downloaded: 4DEW
# Downloading PDB structure '3bir'...
# Downloaded: 3BIR
# Downloading PDB structure '4w54'...
# Downloaded: 4W54
# Downloading PDB structure '4x1g'...
# Downloaded: 4X1G
# Downloading PDB structure '3c9e'...
# Downloaded: 3C9E
# Downloading PDB structure '4ze2'...
# Downloaded: 4ZE2
# Downloading PDB structure '3b25'...
# Downloaded: 3B25
# Downloading PDB structure '5kr1'...
# Downloaded: 5KR1
# Downloading PDB structure '4alg'...
# Downloaded: 4ALG
# Downloading PDB structure '1l5q'...
# Downloaded: 1L5Q
# Downloading PDB structure '1ya3'...
# Downloaded: 1YA3
# Downloading PDB structure '5itp'...
# Downloaded: 5ITP
# Downloading PDB structure '2f78'...
# Downloaded: 2F78
# Downloading PDB structure '4qjr'...
# Downloaded: 4QJR
# Downloading PDB structure '4zla'...
# Downloaded: 4ZLA
# Downloading PDB structure '5fe7'...
# Downloaded: 5FE7
# Downloading PDB structure '1cc6'...
# Downloaded: 1CC6
# Downloading PDB structure '5lht'...
# Downloaded: 5LHT
# Downloading PDB structure '2qx0'...
# Downloaded: 2QX0
# Downloading PDB structure '3vx3'...
# Downloaded: 3VX3
# Downloading PDB structure '3hpi'...
# Downloaded: 3HPI
# Downloading PDB structure '3t1m'...
# Downloaded: 3T1M
# Downloading PDB structure '3f19'...
# Downloaded: 3F19
# Downloading PDB structure '2vc9'...
# Downloaded: 2VC9
# Downloading PDB structure '1hs6'...
# Downloaded: 1HS6
# Downloading PDB structure '1zsb'...
# Downloaded: 1ZSB
# Downloading PDB structure '1uw1'...
# Downloaded: 1UW1
# Downloading PDB structure '1rl8'...
# Downloaded: 1RL8
# Downloading PDB structure '3dnt'...
# Downloaded: 3DNT
# Downloading PDB structure '4f3i'...
# Downloaded: 4F3I
# Downloading PDB structure '2uyw'...
# Downloaded: 2UYW
# Downloading PDB structure '5kxe'...
# Downloaded: 5KXE
# Downloading PDB structure '5e95'...
# Downloaded: 5E95
# Downloading PDB structure '3arp'...
# Downloaded: 3ARP
# Downloading PDB structure '3ujb'...
# Downloaded: 3UJB
# Downloading PDB structure '1gx4'...
# Downloaded: 1GX4
# Downloading PDB structure '2zru'...
# Downloaded: 2ZRU
# Downloading PDB structure '1k6v'...
# Downloaded: 1K6V
# Downloading PDB structure '2idz'...
# Downloaded: 2IDZ
# Downloading PDB structure '4duf'...
# Downloaded: 4DUF
# Downloading PDB structure '1lv8'...
# Downloaded: 1LV8
# Downloading PDB structure '1sh9'...
# Downloaded: 1SH9
# Downloading PDB structure '4csd'...
# Downloaded: 4CSD
# Downloading PDB structure '2f8i'...
# Downloaded: 2F8I
# Downloading PDB structure '3u5l'...
# Downloaded: 3U5L
# Downloading PDB structure '4aje'...
# Downloaded: 4AJE
# Downloading PDB structure '4m13'...
# Downloaded: 4M13
# Downloading PDB structure '2zym'...
# Downloaded: 2ZYM
# Downloading PDB structure '5in5'...
# Downloaded: 5IN5
# Downloading PDB structure '4ugc'...
# Downloaded: 4UGC
# Downloading PDB structure '4jyb'...
# Downloaded: 4JYB
# Downloading PDB structure '3d1z'...
# Downloaded: 3D1Z
# Downloading PDB structure '1odi'...
# Downloaded: 1ODI
# Downloading PDB structure '2qbu'...
# Downloaded: 2QBU
# Downloading PDB structure '4dcu'...
# Downloaded: 4DCU
# Downloading PDB structure '5ioy'...
# Downloaded: 5IOY
# Downloading PDB structure '3oxv'...
# Downloaded: 3OXV
# Downloading PDB structure '1kzn'...
# Downloaded: 1KZN
# Downloading PDB structure '2yiw'...
# Downloaded: 2YIW
# Downloading PDB structure '1mj7'...
# Downloaded: 1MJ7
# Downloading PDB structure '5irr'...
# Downloaded: 5IRR
# Downloading PDB structure '5o2t'...
# Downloaded: 5O2T
# Downloading PDB structure '4e96'...
# Downloaded: 4E96
# Downloading PDB structure '4bqg'...
# Downloaded: 4BQG
# Downloading PDB structure '2gj5'...
# Downloaded: 2GJ5
# Downloading PDB structure '3mss'...
# Downloaded: 3MSS
# Downloading PDB structure '3juq'...
# Downloaded: 3JUQ
# Downloading PDB structure '5ive'...
# Downloaded: 5IVE
# Downloading PDB structure '2h21'...
# Downloaded: 2H21
# Downloading PDB structure '2q7q'...
# Downloaded: 2Q7Q
# Downloading PDB structure '4wf2'...
# Downloaded: 4WF2
# Downloading PDB structure '5ggj'...
# Downloaded: 5GGJ
# Downloading PDB structure '4lzs'...
# Downloaded: 4LZS
# Downloading PDB structure '3r52'...
# Downloaded: 3R52
# Downloading PDB structure '3q9o'...
# Downloaded: 3Q9O
# Downloading PDB structure '4dm6'...
# Downloaded: 4DM6
# Downloading PDB structure '4bup'...
# Downloaded: 4BUP
# Downloading PDB structure '2yfx'...
# Downloaded: 2YFX
# Downloading PDB structure '5lif'...
# Downloaded: 5LIF
# Downloading PDB structure '3dla'...
# Downloaded: 3DLA
# Downloading PDB structure '3axz'...
# Downloaded: 3AXZ
# Downloading PDB structure '3wzn'...
# Downloaded: 3WZN
# Downloading PDB structure '5ufr'...
# Downloaded: 5UFR
# Downloading PDB structure '4fkw'...
# Downloaded: 4FKW
# Downloading PDB structure '2nnp'...
# Downloaded: 2NNP
# Downloading PDB structure '4bi7'...
# Downloaded: 4BI7
# Downloading PDB structure '1xw6'...
# Downloaded: 1XW6
# Downloading PDB structure '2qpq'...
# Downloaded: 2QPQ
# Downloading PDB structure '4uhl'...
# Downloaded: 4UHL
# Downloading PDB structure '4mxp'...
# Downloaded: 4MXP
# Downloading PDB structure '4gh8'...
# Downloaded: 4GH8
# Downloading PDB structure '5f61'...
# Downloaded: 5F61
# Downloading PDB structure '3s71'...
# Downloaded: 3S71
# Downloading PDB structure '1if4'...
# Downloaded: 1IF4
# Downloading PDB structure '3p3s'...
# Downloaded: 3P3S
# Downloading PDB structure '4qb3'...
# Downloaded: 4QB3
# Downloading PDB structure '2d0k'...
# Downloaded: 2D0K
# Downloading PDB structure '5i9z'...
# Downloaded: 5I9Z
# Downloading PDB structure '1n8v'...
# Downloaded: 1N8V
# Downloading PDB structure '5dtw'...
# Downloaded: 5DTW
# Downloading PDB structure '2y7k'...
# Downloaded: 2Y7K
# Downloading PDB structure '2xzw'...
# Downloaded: 2XZW
# Downloading PDB structure '3zno'...
# Downloaded: 3ZNO
# Downloading PDB structure '5g17'...
# Downloaded: 5G17
# Downloading PDB structure '3nq3'...
# Downloaded: 3NQ3
# Downloading PDB structure '3ozc'...
# Downloaded: 3OZC
# Downloading PDB structure '1iwi'...
# Downloaded: 1IWI
# Downloading PDB structure '5mz8'...
# Downloaded: 5MZ8
# Downloading PDB structure '1ha2'...
# Downloaded: 1HA2
# Downloading PDB structure '3kn0'...
# Downloaded: 3KN0
# Downloading PDB structure '5o0a'...
# Downloaded: 5O0A
# Downloading PDB structure '3cla'...
# Downloaded: 3CLA
# Downloading PDB structure '4qxv'...
# Downloaded: 4QXV
# Downloading PDB structure '1o7o'...
# Downloaded: 1O7O
# Downloading PDB structure '3cyu'...
# Downloaded: 3CYU
# Downloading PDB structure '2fvd'...
# Downloaded: 2FVD
# Downloading PDB structure '1fm6'...
# Downloaded: 1FM6
# Downloading PDB structure '3sjt'...
# Downloaded: 3SJT
# Downloading PDB structure '1t7i'...
# Downloaded: 1T7I
# Downloading PDB structure '4ia9'...
# Downloaded: 4IA9
# Downloading PDB structure '2ay5'...
# Downloaded: 2AY5
# Downloading PDB structure '3mj1'...
# Downloaded: 3MJ1
# Downloading PDB structure '5fck'...
# Downloaded: 5FCK
# Downloading PDB structure '1x7x'...
# Downloaded: 1X7X
# Downloading PDB structure '2vxn'...
# Downloaded: 2VXN
# Downloading PDB structure '4fmu'...
# Downloaded: 4FMU
# Downloading PDB structure '3kdd'...
# Downloaded: 3KDD
# Downloading PDB structure '2zfs'...
# Downloaded: 2ZFS
# Downloading PDB structure '3kqp'...
# Downloaded: 3KQP
# Downloading PDB structure '5jhb'...
# Downloaded: 5JHB
# Downloading PDB structure '1e8g'...
# Downloaded: 1E8G
# Downloading PDB structure '4nks'...
# Downloaded: 4NKS
# Downloading PDB structure '2jfz'...
# Downloaded: 2JFZ
# Downloading PDB structure '3juo'...
# Downloaded: 3JUO
# Downloading PDB structure '2haw'...
# Downloaded: 2HAW
# Downloading PDB structure '5e89'...
# Downloaded: 5E89
# Downloading PDB structure '3n1c'...
# Downloaded: 3N1C
# Downloading PDB structure '4rr7'...
# Downloaded: 4RR7
# Downloading PDB structure '3d78'...
# Downloaded: 3D78
# Downloading PDB structure '1vyg'...
# Downloaded: 1VYG
# Downloading PDB structure '4cc5'...
# Downloaded: 4CC5
# Downloading PDB structure '5ab9'...
# Downloaded: 5AB9
# Downloading PDB structure '4q09'...
# Downloaded: 4Q09
# Downloading PDB structure '3hdq'...
# Downloaded: 3HDQ
# Downloading PDB structure '2a06'...
# Downloaded: 2A06
# Downloading PDB structure '4fki'...
# Downloaded: 4FKI
# Downloading PDB structure '1det'...
# Downloaded: 1DET
# Downloading PDB structure '4r57'...
# Downloaded: 4R57
# Downloading PDB structure '5a82'...
# Downloaded: 5A82
# Downloading PDB structure '3lzv'...
# Downloaded: 3LZV
# Downloading PDB structure '2xde'...
# Downloaded: 2XDE
# Downloading PDB structure '5e2m'...
# Downloaded: 5E2M
# Downloading PDB structure '1fby'...
# Downloaded: 1FBY
# Downloading PDB structure '3zsz'...
# Downloaded: 3ZSZ
# Downloading PDB structure '3mg5'...
# Downloaded: 3MG5
# Downloading PDB structure '1y93'...
# Downloaded: 1Y93
# Downloading PDB structure '5his'...
# Downloaded: 5HIS
# Downloading PDB structure '2fr3'...
# Downloaded: 2FR3
# Downloading PDB structure '3lle'...
# Downloaded: 3LLE
# Downloading PDB structure '5gwe'...
# Downloaded: 5GWE
# Downloading PDB structure '3n7a'...
# Downloaded: 3N7A
# Downloading PDB structure '3l8s'...
# Downloaded: 3L8S
# Downloading PDB structure '1d2e'...
# Downloaded: 1D2E
# Downloading PDB structure '5exw'...
# Downloaded: 5EXW
# Downloading PDB structure '3zt4'...
# Downloaded: 3ZT4
# Downloading PDB structure '4xoe'...
# Downloaded: 4XOE
# Downloading PDB structure '3jxu'...
# Downloaded: 3JXU
# Downloading PDB structure '2hyy'...
# Downloaded: 2HYY
# Downloading PDB structure '3wtm'...
# Downloaded: 3WTM
# Downloading PDB structure '2zq2'...
# Downloaded: 2ZQ2
# Downloading PDB structure '1v16'...
# Downloaded: 1V16
# Downloading PDB structure '3k5i'...
# Downloaded: 3K5I
# Downloading PDB structure '1o7q'...
# Downloaded: 1O7Q
# Downloading PDB structure '5ut6'...
# Downloaded: 5UT6
# Downloading PDB structure '4y4j'...
# Downloaded: 4Y4J
# Downloading PDB structure '1qyg'...
# Downloaded: 1QYG
# Downloading PDB structure '5tbm'...
# Downloaded: 5TBM
# Downloading PDB structure '3p5o'...
# Downloaded: 3P5O
# Downloading PDB structure '2vpo'...
# Downloaded: 2VPO
# Downloading PDB structure '4jmz'...
# Downloaded: 4JMZ
# Downloading PDB structure '2vmd'...
# Downloaded: 2VMD
# Downloading PDB structure '2buv'...
# Downloaded: 2BUV
# Downloading PDB structure '2yi7'...
# Downloaded: 2YI7
# Downloading PDB structure '2fw6'...
# Downloaded: 2FW6
# Downloading PDB structure '4unp'...
# Downloaded: 4UNP
# Downloading PDB structure '2xjx'...
# Downloaded: 2XJX
# Downloading PDB structure '2hf9'...
# Downloaded: 2HF9
# Downloading PDB structure '2h5a'...
# Downloaded: 2H5A
# Downloading PDB structure '4qo7'...
# Downloaded: 4QO7
# Downloading PDB structure '1osv'...
# Downloaded: 1OSV
# Downloading PDB structure '2we3'...
# Downloaded: 2WE3
# Downloading PDB structure '3ivc'...
# Downloaded: 3IVC
# Downloading PDB structure '4ffs'...
# Downloaded: 4FFS
# Downloading PDB structure '3kyq'...
# Downloaded: 3KYQ
# Downloading PDB structure '4km2'...
# Downloaded: 4KM2
# Downloading PDB structure '4ueh'...
# Downloaded: 4UEH
# Downloading PDB structure '3eky'...
# Downloaded: 3EKY
# Downloading PDB structure '2y1w'...
# Downloaded: 2Y1W
# Downloading PDB structure '4q4p'...
# Downloaded: 4Q4P
# Downloading PDB structure '1oim'...
# Downloaded: 1OIM
# Downloading PDB structure '1xh6'...
# Downloaded: 1XH6
# Downloading PDB structure '2o4s'...
# Downloaded: 2O4S
# Downloading PDB structure '3qip'...
# Downloaded: 3QIP
# Downloading PDB structure '3r6u'...
# Downloaded: 3R6U
# Downloading PDB structure '5cfm'...
# Downloaded: 5CFM
# Downloading PDB structure '1oar'...
# Downloaded: 1OAR
# Downloading PDB structure '3k02'...
# Downloaded: 3K02
# Downloading PDB structure '1dru'...
# Downloaded: 1DRU
# Downloading PDB structure '4xt2'...
# Downloaded: 4XT2
# Downloading PDB structure '1e7v'...
# Downloaded: 1E7V
# Downloading PDB structure '5t7i'...
# Downloaded: 5T7I
# Downloading PDB structure '5eh8'...
# Downloaded: 5EH8
# Downloading PDB structure '1uho'...
# Downloaded: 1UHO
# Downloading PDB structure '3r5r'...
# Downloaded: 3R5R
# Downloading PDB structure '3d7f'...
# Downloaded: 3D7F
# Downloading PDB structure '3h7w'...
# Downloaded: 3H7W
# Downloading PDB structure '3rgf'...
# Downloaded: 3RGF
# Downloading PDB structure '4kub'...
# Downloaded: 4KUB
# Downloading PDB structure '3myg'...
# Downloaded: 3MYG
# Downloading PDB structure '2whw'...
# Downloaded: 2WHW
# Downloading PDB structure '1xbb'...
# Downloaded: 1XBB
# Downloading PDB structure '2j77'...
# Downloaded: 2J77
# Downloading PDB structure '3hec'...
# Downloaded: 3HEC
# Downloading PDB structure '5h9r'...
# Downloaded: 5H9R
# Downloading PDB structure '1gah'...
# Downloaded: 1GAH
# Downloading PDB structure '5j5g'...
# Downloaded: 5J5G
# Downloading PDB structure '3t2t'...
# Downloaded: 3T2T
# Downloading PDB structure '3ryj'...
# Downloaded: 3RYJ
# Downloading PDB structure '4lpg'...
# Downloaded: 4LPG
# Downloading PDB structure '4fzj'...
# Downloaded: 4FZJ
# Downloading PDB structure '2ca8'...
# Downloaded: 2CA8
# Downloading PDB structure '5ta4'...
# Downloaded: 5TA4
# Downloading PDB structure '5ie3'...
# Downloaded: 5IE3
# Downloading PDB structure '4rwl'...
# Downloaded: 4RWL
# Downloading PDB structure '1ew8'...
# Downloaded: 1EW8
# Downloading PDB structure '4n6h'...
# Downloaded: 4N6H
# Downloading PDB structure '2wq5'...
# Downloaded: 2WQ5
# Downloading PDB structure '5jaq'...
# Downloaded: 5JAQ
# Downloading PDB structure '1i1e'...
# Downloaded: 1I1E
# Downloading PDB structure '3q72'...
# Downloaded: 3Q72
# Downloading PDB structure '5k2a'...
# Downloaded: 5K2A
# Downloading PDB structure '5ka9'...
# Downloaded: 5KA9
# Downloading PDB structure '4jlh'...
# Downloaded: 4JLH
# Downloading PDB structure '2izh'...
# Downloaded: 2IZH
# Downloading PDB structure '2o1v'...
# Downloaded: 2O1V
# Downloading PDB structure '1jmg'...
# Downloaded: 1JMG
# Downloading PDB structure '4q6e'...
# Downloaded: 4Q6E
# Downloading PDB structure '1akt'...
# Downloaded: 1AKT
# Downloading PDB structure '4abd'...
# Downloaded: 4ABD
# Downloading PDB structure '4eu0'...
# Downloaded: 4EU0
# Downloading PDB structure '4oex'...
# Downloaded: 4OEX
# Downloading PDB structure '2ovv'...
# Downloaded: 2OVV
# Downloading PDB structure '1h0a'...
# Downloaded: 1H0A
# Downloading PDB structure '5am6'...
# Downloaded: 5AM6
# Downloading PDB structure '1swg'...
# Downloaded: 1SWG
# Downloading PDB structure '5khj'...
# Downloaded: 5KHJ
# Downloading PDB structure '1lif'...
# Downloaded: 1LIF
# Downloading PDB structure '4x50'...
# Downloaded: 4X50
# Downloading PDB structure '5f3t'...
# Downloaded: 5F3T
# Downloading PDB structure '1toi'...
# Downloaded: 1TOI
# Downloading PDB structure '1qfy'...
# Downloaded: 1QFY
# Downloading PDB structure '2hnx'...
# Downloaded: 2HNX
# Downloading PDB structure '2arm'...
# Downloaded: 2ARM
# Downloading PDB structure '5a5v'...
# Downloaded: 5A5V
# Downloading PDB structure '5nkc'...
# Downloaded: 5NKC
# Downloading PDB structure '3lk8'...
# Downloaded: 3LK8
# Downloading PDB structure '1d2v'...
# Downloaded: 1D2V
# Downloading PDB structure '1y6q'...
# Downloaded: 1Y6Q
# Downloading PDB structure '5ldq'...
# Downloaded: 5LDQ
# Downloading PDB structure '4nxv'...
# Downloaded: 4NXV
# Downloading PDB structure '4lbp'...
# Downloaded: 4LBP
# Downloading PDB structure '2drc'...
# Downloaded: 2DRC
# Downloading PDB structure '4ekq'...
# Downloaded: 4EKQ
# Downloading PDB structure '1g53'...
# Downloaded: 1G53
# Downloading PDB structure '5kat'...
# Downloaded: 5KAT
# Downloading PDB structure '4zcc'...
# Downloaded: 4ZCC
# Downloading PDB structure '4tqk'...
# Downloaded: 4TQK
# Downloading PDB structure '1pg0'...
# Downloaded: 1PG0
# Downloading PDB structure '2hqu'...
# Downloaded: 2HQU
# Downloading PDB structure '2i4v'...
# Downloaded: 2I4V
# Downloading PDB structure '5twj'...
# Downloaded: 5TWJ
# Downloading PDB structure '3cyx'...
# Downloaded: 3CYX
# Downloading PDB structure '2h79'...
# Downloaded: 2H79
# Downloading PDB structure '3vw1'...
# Downloaded: 3VW1
# Downloading PDB structure '5f1r'...
# Downloaded: 5F1R
# Downloading PDB structure '3hv8'...
# Downloaded: 3HV8
# Downloading PDB structure '4br3'...
# Downloaded: 4BR3
# Downloading PDB structure '1urg'...
# Downloaded: 1URG
# Downloading PDB structure '2ay8'...
# Downloaded: 2AY8
# Downloading PDB structure '1opb'...
# Downloaded: 1OPB
# Downloading PDB structure '3euf'...
# Downloaded: 3EUF
# Downloading PDB structure '3d0e'...
# Downloaded: 3D0E
# Downloading PDB structure '3uo4'...
# Downloaded: 3UO4
# Downloading PDB structure '3r1v'...
# Downloaded: 3R1V
# Downloading PDB structure '1duv'...
# Downloaded: 1DUV
# Downloading PDB structure '3bpc'...
# Downloaded: 3BPC
# Downloading PDB structure '2a4l'...
# Downloaded: 2A4L
# Downloading PDB structure '1udt'...
# Downloaded: 1UDT
# Downloading PDB structure '2o3p'...
# Downloaded: 2O3P
# Downloading PDB structure '3uq8'...
# Downloaded: 3UQ8
# Downloading PDB structure '2y1d'...
# Downloaded: 2Y1D
# Downloading PDB structure '2v57'...
# Downloaded: 2V57
# Downloading PDB structure '5l94'...
# Downloaded: 5L94
# Downloading PDB structure '3ucb'...
# Downloaded: 3UCB
# Downloading PDB structure '2r09'...
# Downloaded: 2R09
# Downloading PDB structure '4ipi'...
# Downloaded: 4IPI
# Downloading PDB structure '2pdl'...
# Downloaded: 2PDL
# Downloading PDB structure '4loj'...
# Downloaded: 4LOJ
# Downloading PDB structure '3mmr'...
# Downloaded: 3MMR
# Downloading PDB structure '4efk'...
# Downloaded: 4EFK
# Downloading PDB structure '5lat'...
# Downloaded: 5LAT
# Downloading PDB structure '3mxf'...
# Downloaded: 3MXF
# Downloading PDB structure '4z69'...
# Downloaded: 4Z69
# Downloading PDB structure '2clo'...
# Downloaded: 2CLO
# Downloading PDB structure '4al4'...
# Downloaded: 4AL4
# Downloading PDB structure '2ii3'...
# Downloaded: 2II3
# Downloading PDB structure '5fpp'...
# Downloaded: 5FPP
# Downloading PDB structure '4pin'...
# Downloaded: 4PIN
# Downloading PDB structure '4xv4'...
# Downloaded: 4XV4
# Downloading PDB structure '4er3'...
# Downloaded: 4ER3
# Downloading PDB structure '2vku'...
# Downloaded: 2VKU
# Downloading PDB structure '4ddh'...
# Downloaded: 4DDH
# Downloading PDB structure '5te0'...
# Downloaded: 5TE0
# Downloading PDB structure '2qeh'...
# Downloaded: 2QEH
# Downloading PDB structure '3buf'...
# Downloaded: 3BUF
# Downloading PDB structure '5hjg'...
# Downloaded: 5HJG
# Downloading PDB structure '4eo8'...
# Downloaded: 4EO8
# Downloading PDB structure '1gt1'...
# Downloaded: 1GT1
# Downloading PDB structure '4fvq'...
# Downloaded: 4FVQ
# Downloading PDB structure '3zsi'...
# Downloaded: 3ZSI
# Downloading PDB structure '4oic'...
# Downloaded: 4OIC
# Downloading PDB structure '4rmd'...
# Downloaded: 4RMD
# Downloading PDB structure '1gw6'...
# Downloaded: 1GW6
# Downloading PDB structure '2npq'...
# Downloaded: 2NPQ
# Downloading PDB structure '3quz'...
# Downloaded: 3QUZ
# Downloading PDB structure '3bva'...
# Downloaded: 3BVA
# Downloading PDB structure '1sz0'...
# Downloaded: 1SZ0
# Downloading PDB structure '5d26'...
# Downloaded: 5D26
# Downloading PDB structure '4id1'...
# Downloaded: 4ID1
# Downloading PDB structure '2aa6'...
# Downloaded: 2AA6
# Downloading PDB structure '2bmk'...
# Downloaded: 2BMK
# Downloading PDB structure '4xu3'...
# Downloaded: 4XU3
# Downloading PDB structure '5htk'...
# Downloaded: 5HTK
# Downloading PDB structure '2qfo'...
# Downloaded: 2QFO
# Downloading PDB structure '3b82'...
# Downloaded: 3B82
# Downloading PDB structure '4rpo'...
# Downloaded: 4RPO
# Downloading PDB structure '2nmz'...
# Downloaded: 2NMZ
# Downloading PDB structure '2yk1'...
# Downloaded: 2YK1
# Downloading PDB structure '4l9i'...
# Downloaded: 4L9I
# Downloading PDB structure '3ndt'...
# Downloaded: 3NDT
# Downloading PDB structure '3qoa'...
# Downloaded: 3QOA
# Downloading PDB structure '2idw'...
# Downloaded: 2IDW
# Downloading PDB structure '5ftg'...
# Downloaded: 5FTG
# Downloading PDB structure '3p7i'...
# Downloaded: 3P7I
# Downloading PDB structure '3qrj'...
# Downloaded: 3QRJ
# Downloading PDB structure '4ajh'...
# Downloaded: 4AJH
# Downloading PDB structure '4urz'...
# Downloaded: 4URZ
# Downloading PDB structure '3skk'...
# Downloaded: 3SKK
# Downloading PDB structure '3m0i'...
# Downloaded: 3M0I
# Downloading PDB structure '4ugn'...
# Downloaded: 4UGN
# Downloading PDB structure '3luj'...
# Downloaded: 3LUJ
# Downloading PDB structure '1m01'...
# Downloaded: 1M01
# Downloading PDB structure '5adv'...
# Downloaded: 5ADV
# Downloading PDB structure '3r3c'...
# Downloaded: 3R3C
# Downloading PDB structure '2qwl'...
# Downloaded: 2QWL
# Downloading PDB structure '2zdk'...
# Downloaded: 2ZDK
# Downloading PDB structure '4dcx'...
# Downloaded: 4DCX
# Downloading PDB structure '5iot'...
# Downloaded: 5IOT
# Downloading PDB structure '1h0r'...
# Downloaded: 1H0R
# Downloading PDB structure '4fe9'...
# Downloaded: 4FE9
# Downloading PDB structure '5igk'...
# Downloaded: 5IGK
# Downloading PDB structure '1swt'...
# Downloaded: 1SWT
# Downloading PDB structure '1d3d'...
# Downloaded: 1D3D
# Downloading PDB structure '3hua'...
# Downloaded: 3HUA
# Downloading PDB structure '4bqj'...
# Downloaded: 4BQJ
# Downloading PDB structure '5n16'...
# Downloaded: 5N16
# Downloading PDB structure '1m2z'...
# Downloaded: 1M2Z
# Downloading PDB structure '1ykj'...
# Downloaded: 1YKJ
# Downloading PDB structure '4wmy'...
# Downloaded: 4WMY
# Downloading PDB structure '3pb3'...
# Downloaded: 3PB3
# Downloading PDB structure '4q3s'...
# Downloaded: 4Q3S
# Downloading PDB structure '5l1u'...
# Downloaded: 5L1U
# Downloading PDB structure '4ll3'...
# Downloaded: 4LL3
# Downloading PDB structure '1drf'...
# Downloaded: 1DRF
# Downloading PDB structure '3p9t'...
# Downloaded: 3P9T
# Downloading PDB structure '1q9d'...
# Downloaded: 1Q9D
# Downloading PDB structure '3ap6'...
# Downloaded: 3AP6
# Downloading PDB structure '1fcx'...
# Downloaded: 1FCX
# Downloading PDB structure '3b28'...
# Downloaded: 3B28
# Downloading PDB structure '3tct'...
# Downloaded: 3TCT
# Downloading PDB structure '1y2f'...
# Downloaded: 1Y2F
# Downloading PDB structure '5u5y'...
# Downloaded: 5U5Y
# Downloading PDB structure '4j0r'...
# Downloaded: 4J0R
# Downloading PDB structure '2pfy'...
# Downloaded: 2PFY
# Downloading PDB structure '3hmo'...
# Downloaded: 3HMO
# Downloading PDB structure '3ka2'...
# Downloaded: 3KA2
# Downloading PDB structure '5gsa'...
# Downloaded: 5GSA
# Downloading PDB structure '4lnx'...
# Downloaded: 4LNX
# Downloading PDB structure '2fqy'...
# Downloaded: 2FQY
# Downloading PDB structure '3s7b'...
# Downloaded: 3S7B
# Downloading PDB structure '5etl'...
# Downloaded: 5ETL
# Downloading PDB structure '2flr'...
# Downloaded: 2FLR
# Downloading PDB structure '3aye'...
# Downloaded: 3AYE
# Downloading PDB structure '3hsc'...
# Downloaded: 3HSC
# Downloading PDB structure '3ryy'...
# Downloaded: 3RYY
# Downloading PDB structure '5ewk'...
# Downloaded: 5EWK
# Downloading PDB structure '2fou'...
# Downloaded: 2FOU
# Downloading PDB structure '4ido'...
# Downloaded: 4IDO
# Downloading PDB structure '5gmm'...
# Downloaded: 5GMM
# Downloading PDB structure '1pk8'...
# Downloaded: 1PK8
# Downloading PDB structure '5f25'...
# Downloaded: 5F25
# Downloading PDB structure '1yei'...
# Downloaded: 1YEI
# Downloading PDB structure '4i8x'...
# Downloaded: 4I8X
# Downloading PDB structure '4udw'...
# Downloaded: 4UDW
# Downloading PDB structure '5kb3'...
# Downloaded: 5KB3
# Downloading PDB structure '1g6t'...
# Downloaded: 1G6T
# Downloading PDB structure '3h1x'...
# Downloaded: 3H1X
# Downloading PDB structure '4b5s'...
# Downloaded: 4B5S
# Downloading PDB structure '2qjy'...
# Downloaded: 2QJY
# Downloading PDB structure '4omj'...
# Downloaded: 4OMJ
# Downloading PDB structure '1pgp'...
# Downloaded: 1PGP
# Downloading PDB structure '3ru1'...
# Downloaded: 3RU1
# Downloading PDB structure '4luo'...
# Downloaded: 4LUO
# Downloading PDB structure '1bnw'...
# Downloaded: 1BNW
# Downloading PDB structure '1tlc'...
# Downloaded: 1TLC
# Downloading PDB structure '1h8s'...
# Downloaded: 1H8S
# Downloading PDB structure '5khg'...
# Downloaded: 5KHG
# Downloading PDB structure '3k4v'...
# Downloaded: 3K4V
# Downloading PDB structure '4ijl'...
# Downloaded: 4IJL
# Downloading PDB structure '1zhx'...
# Downloaded: 1ZHX
# Downloading PDB structure '2fav'...
# Downloaded: 2FAV
# Downloading PDB structure '4r0a'...
# Downloaded: 4R0A
# Downloading PDB structure '4co0'...
# Downloaded: 4CO0
# Downloading PDB structure '3gy3'...
# Downloaded: 3GY3
# Downloading PDB structure '1ecm'...
# Downloaded: 1ECM
# Downloading PDB structure '1qft'...
# Downloaded: 1QFT
# Downloading PDB structure '2agt'...
# Downloaded: 2AGT
# Downloading PDB structure '3gcv'...
# Downloaded: 3GCV
# Downloading PDB structure '4azg'...
# Downloaded: 4AZG
# Downloading PDB structure '4k9w'...
# Downloaded: 4K9W
# Downloading PDB structure '5duv'...
# Downloaded: 5DUV
# Downloading PDB structure '2bys'...
# Downloaded: 2BYS
# Downloading PDB structure '4ly9'...
# Downloaded: 4LY9
# Downloading PDB structure '4ywp'...
# Downloaded: 4YWP
# Downloading PDB structure '4bk1'...
# Downloaded: 4BK1
# Downloading PDB structure '3lxn'...
# Downloaded: 3LXN
# Downloading PDB structure '4jwl'...
# Downloaded: 4JWL
# Downloading PDB structure '5eh5'...
# Downloaded: 5EH5
# Downloading PDB structure '4rrd'...
# Downloaded: 4RRD
# Downloading PDB structure '2p4s'...
# Downloaded: 2P4S
# Downloading PDB structure '3d7k'...
# Downloaded: 3D7K
# Downloading PDB structure '1x8d'...
# Downloaded: 1X8D
# Downloading PDB structure '1meu'...
# Downloaded: 1MEU
# Downloading PDB structure '3ckb'...
# Downloaded: 3CKB
# Downloading PDB structure '4zyf'...
# Downloaded: 4ZYF
# Downloading PDB structure '4cj5'...
# Downloaded: 4CJ5
# Downloading PDB structure '5etr'...
# Downloaded: 5ETR
# Downloading PDB structure '2qm7'...
# Downloaded: 2QM7
# Downloading PDB structure '1gwv'...
# Downloaded: 1GWV
# Downloading PDB structure '2v3u'...
# Downloaded: 2V3U
# Downloading PDB structure '1ttm'...
# Downloaded: 1TTM
# Downloading PDB structure '4m5i'...
# Downloaded: 4M5I
# Downloading PDB structure '1rd4'...
# Downloaded: 1RD4
# Downloading PDB structure '3mhi'...
# Downloaded: 3MHI
# Downloading PDB structure '3d20'...
# Downloaded: 3D20
# Downloading PDB structure '1lvu'...
# Downloaded: 1LVU
# Downloading PDB structure '43ca'...
# Downloaded: 43CA
# Downloading PDB structure '2pjo'...
# Downloaded: 2PJO
# Downloading PDB structure '5nvv'...
# Downloaded: 5NVV
# Downloading PDB structure '1tpz'...
# Downloaded: 1TPZ
# Downloading PDB structure '4p5y'...
# Downloaded: 4P5Y
# Downloading PDB structure '4zvi'...
# Downloaded: 4ZVI
# Downloading PDB structure '5gid'...
# Downloaded: 5GID
# Downloading PDB structure '4kot'...
# Downloaded: 4KOT
# Downloading PDB structure '4ggz'...
# Downloaded: 4GGZ
# Downloading PDB structure '3oyw'...
# Downloaded: 3OYW
# Downloading PDB structure '1z95'...
# Downloaded: 1Z95
# Downloading PDB structure '4cx1'...
# Downloaded: 4CX1
# Downloading PDB structure '1n43'...
# Downloaded: 1N43
# Downloading PDB structure '4v04'...
# Downloaded: 4V04
# Downloading PDB structure '5cjh'...
# Downloaded: 5CJH
# Downloading PDB structure '3a1t'...
# Downloaded: 3A1T
# Downloading PDB structure '2p0d'...
# Downloaded: 2P0D
# Downloading PDB structure '3ljj'...
# Downloaded: 3LJJ
# Downloading PDB structure '3nex'...
# Downloaded: 3NEX
# Downloading PDB structure '225l'...
# Downloaded: 225L
# Downloading PDB structure '2imd'...
# Downloaded: 2IMD
# Downloading PDB structure '1u72'...
# Downloaded: 1U72
# Downloading PDB structure '4ge1'...
# Downloaded: 4GE1
# Downloading PDB structure '3ekt'...
# Downloaded: 3EKT
# Downloading PDB structure '4gwk'...
# Downloaded: 4GWK
# Downloading PDB structure '4pv0'...
# Downloaded: 4PV0
# Downloading PDB structure '4h5t'...
# Downloaded: 4H5T
# Downloading PDB structure '4ipw'...
# Downloaded: 4IPW
# Downloading PDB structure '2yel'...
# Downloaded: 2YEL
# Downloading PDB structure '5klp'...
# Downloaded: 5KLP
# Downloading PDB structure '5ivv'...
# Downloaded: 5IVV
# Downloading PDB structure '2w97'...
# Downloaded: 2W97
# Downloading PDB structure '2vb8'...
# Downloaded: 2VB8
# Downloading PDB structure '2hjb'...
# Downloaded: 2HJB
# Downloading PDB structure '5gof'...
# Downloaded: 5GOF
# Downloading PDB structure '1lo7'...
# Downloaded: 1LO7
# Downloading PDB structure '4dqb'...
# Downloaded: 4DQB
# Downloading PDB structure '2j7d'...
# Downloaded: 2J7D
# Downloading PDB structure '1h60'...
# Downloaded: 1H60
# Downloading PDB structure '1u27'...
# Downloaded: 1U27
# Downloading PDB structure '3o8u'...
# Downloaded: 3O8U
# Downloading PDB structure '4dli'...
# Downloaded: 4DLI
# Downloading PDB structure '183l'...
# Downloaded: 183L
# Downloading PDB structure '4q1x'...
# Downloaded: 4Q1X
# Downloading PDB structure '5acx'...
# Downloaded: 5ACX
# Downloading PDB structure '4don'...
# Downloaded: 4DON
# Downloading PDB structure '1m48'...
# Downloaded: 1M48
# Downloading PDB structure '4wya'...
# Downloaded: 4WYA
# Downloading PDB structure '1g1d'...
# Downloaded: 1G1D
# Downloading PDB structure '3img'...
# Downloaded: 3IMG
# Downloading PDB structure '4asj'...
# Downloaded: 4ASJ
# Downloading PDB structure '2qfq'...
# Downloaded: 2QFQ
# Downloading PDB structure '4yvb'...
# Downloaded: 4YVB
# Downloading PDB structure '4mnp'...
# Downloaded: 4MNP
# Downloading PDB structure '3u9w'...
# Downloaded: 3U9W
# Downloading PDB structure '2wxp'...
# Downloaded: 2WXP
# Downloading PDB structure '3rbu'...
# Downloaded: 3RBU
# Downloading PDB structure '2xi7'...
# Downloaded: 2XI7
# Downloading PDB structure '4kmz'...
# Downloaded: 4KMZ
# Downloading PDB structure '4bqo'...
# Downloaded: 4BQO
# Downloading PDB structure '1c5c'...
# Downloaded: 1C5C
# Downloading PDB structure '4w9j'...
# Downloaded: 4W9J
# Downloading PDB structure '3mwl'...
# Downloaded: 3MWL
# Downloading PDB structure '1iut'...
# Downloaded: 1IUT
# Downloading PDB structure '5ioq'...
# Downloaded: 5IOQ
# Downloading PDB structure '2ve3'...
# Downloaded: 2VE3
# Downloading PDB structure '4tmw'...
# Downloaded: 4TMW
# Downloading PDB structure '2wnc'...
# Downloaded: 2WNC
# Downloading PDB structure '4m8h'...
# Downloaded: 4M8H
# Downloading PDB structure '4txc'...
# Downloaded: 4TXC
# Downloading PDB structure '2q0i'...
# Downloaded: 2Q0I
# Downloading PDB structure '4z93'...
# Downloaded: 4Z93
# Downloading PDB structure '3pg3'...
# Downloaded: 3PG3
# Downloading PDB structure '4u43'...
# Downloaded: 4U43
# Downloading PDB structure '4ugk'...
# Downloaded: 4UGK
# Downloading PDB structure '5fjn'...
# Downloaded: 5FJN
# Downloading PDB structure '2zdn'...
# Downloaded: 2ZDN
# Downloading PDB structure '1pot'...
# Downloaded: 1POT
# Downloading PDB structure '2c1q'...
# Downloaded: 2C1Q
# Downloading PDB structure '2vyt'...
# Downloaded: 2VYT
# Downloading PDB structure '3r3f'...
# Downloaded: 3R3F
# Downloading PDB structure '3gnw'...
# Downloaded: 3GNW
# Downloading PDB structure '1jpz'...
# Downloaded: 1JPZ
# Downloading PDB structure '5g1a'...
# Downloaded: 5G1A
# Downloading PDB structure '2qtn'...
# Downloaded: 2QTN
# Downloading PDB structure '4uyg'...
# Downloaded: 4UYG
# Downloading PDB structure '2y8l'...
# Downloaded: 2Y8L
# Downloading PDB structure '5nk8'...
# Downloaded: 5NK8
# Downloading PDB structure '5mge'...
# Downloaded: 5MGE
# Downloading PDB structure '1i9l'...
# Downloaded: 1I9L
# Downloading PDB structure '4np2'...
# Downloaded: 4NP2
# Downloading PDB structure '3pd4'...
# Downloaded: 3PD4
# Downloading PDB structure '3b78'...
# Downloaded: 3B78
# Downloading PDB structure '1upw'...
# Downloaded: 1UPW
# Downloading PDB structure '5gmh'...
# Downloaded: 5GMH
# Downloading PDB structure '3c39'...
# Downloaded: 3C39
# Downloading PDB structure '3em3'...
# Downloaded: 3EM3
# Downloading PDB structure '4zzz'...
# Downloaded: 4ZZZ
# Downloading PDB structure '3arx'...
# Downloaded: 3ARX
# Downloading PDB structure '2f47'...
# Downloaded: 2F47
# Downloading PDB structure '3a73'...
# Downloaded: 3A73
# Downloading PDB structure '2rin'...
# Downloaded: 2RIN
# Downloading PDB structure '3myq'...
# Downloaded: 3MYQ
# Downloading PDB structure '4btj'...
# Downloaded: 4BTJ
# Downloading PDB structure '3mdz'...
# Downloaded: 3MDZ
# Downloading PDB structure '3alt'...
# Downloaded: 3ALT
# Downloading PDB structure '4gue'...
# Downloaded: 4GUE
# Downloading PDB structure '2qx8'...
# Downloaded: 2QX8
# Downloading PDB structure '2rte'...
# Downloaded: 2RTE
# Downloading PDB structure '2jdy'...
# Downloaded: 2JDY
# Downloading PDB structure '5d1j'...
# Downloaded: 5D1J
# Downloading PDB structure '2bgd'...
# Downloaded: 2BGD
# Downloading PDB structure '3cj5'...
# Downloaded: 3CJ5
# Downloading PDB structure '5iu4'...
# Downloaded: 5IU4
# Downloading PDB structure '3zlr'...
# Downloaded: 3ZLR
# Downloading PDB structure '4r43'...
# Downloaded: 4R43
# Downloading PDB structure '4lo1'...
# Downloaded: 4LO1
# Downloading PDB structure '5i3x'...
# Downloaded: 5I3X
# Downloading PDB structure '1fkb'...
# Downloaded: 1FKB
# Downloading PDB structure '4hmq'...
# Downloaded: 4HMQ
# Downloading PDB structure '3vqh'...
# Downloaded: 3VQH
# Downloading PDB structure '3zyf'...
# Downloaded: 3ZYF
# Downloading PDB structure '4l4v'...
# Downloaded: 4L4V
# Downloading PDB structure '5l9o'...
# Downloaded: 5L9O
# Downloading PDB structure '5ulp'...
# Downloaded: 5ULP
# Downloading PDB structure '4r74'...
# Downloaded: 4R74
# Downloading PDB structure '4o33'...
# Downloaded: 4O33
# Downloading PDB structure '5i7o'...
# Downloaded: 5I7O
# Downloading PDB structure '3tzm'...
# Downloaded: 3TZM
# Downloading PDB structure '3evd'...
# Downloaded: 3EVD
# Downloading PDB structure '4cgj'...
# Downloaded: 4CGJ
# Downloading PDB structure '4ej8'...
# Downloaded: 4EJ8
# Downloading PDB structure '4jnk'...
# Downloaded: 4JNK
# Downloading PDB structure '4gs9'...
# Downloaded: 4GS9
# Downloading PDB structure '1ceb'...
# Downloaded: 1CEB
# Downloading PDB structure '1flr'...
# Downloaded: 1FLR
# Downloading PDB structure '4ug5'...
# Downloaded: 4UG5
# Downloading PDB structure '1qqn'...
# Downloaded: 1QQN
# Downloading PDB structure '4lar'...
# Downloaded: 4LAR
# Downloading PDB structure '4tqn'...
# Downloaded: 4TQN
# Downloading PDB structure '1z11'...
# Downloaded: 1Z11
# Downloading PDB structure '4cp5'...
# Downloaded: 4CP5
# Downloading PDB structure '1u5b'...
# Downloaded: 1U5B
# Downloading PDB structure '4f7v'...
# Downloaded: 4F7V
# Downloading PDB structure '4aw8'...
# Downloaded: 4AW8
# Downloading PDB structure '4fl1'...
# Downloaded: 4FL1
# Downloading PDB structure '1h9z'...
# Downloaded: 1H9Z
# Downloading PDB structure '1d2s'...
# Downloaded: 1D2S
# Downloading PDB structure '1lke'...
# Downloaded: 1LKE
# Downloading PDB structure '5f2p'...
# Downloaded: 5F2P
# Downloading PDB structure '5cu3'...
# Downloaded: 5CU3
# Downloading PDB structure '3fsj'...
# Downloaded: 3FSJ
# Downloading PDB structure '4lwa'...
# Downloaded: 4LWA
# Downloading PDB structure '5vse'...
# Downloaded: 5VSE
# Downloading PDB structure '4i7l'...
# Downloaded: 4I7L
# Downloading PDB structure '2gyu'...
# Downloaded: 2GYU
# Downloading PDB structure '4g0p'...
# Downloaded: 4G0P
# Downloading PDB structure '1jif'...
# Downloaded: 1JIF
# Downloading PDB structure '4wyz'...
# Downloaded: 4WYZ
# Downloading PDB structure '1k1n'...
# Downloaded: 1K1N
# Downloading PDB structure '4bj8'...
# Downloaded: 4BJ8
# Downloading PDB structure '2vhw'...
# Downloaded: 2VHW
# Downloading PDB structure '4er6'...
# Downloaded: 4ER6
# Downloading PDB structure '4d75'...
# Downloaded: 4D75
# Downloading PDB structure '5ia2'...
# Downloaded: 5IA2
# Downloading PDB structure '4ddm'...
# Downloaded: 4DDM
# Downloading PDB structure '3jw2'...
# Downloaded: 3JW2
# Downloading PDB structure '1gt4'...
# Downloaded: 1GT4
# Downloading PDB structure '4mes'...
# Downloaded: 4MES
# Downloading PDB structure '1okn'...
# Downloaded: 1OKN
# Downloading PDB structure '4ktf'...
# Downloaded: 4KTF
# Downloading PDB structure '4loo'...
# Downloaded: 4LOO
# Downloading PDB structure '4o0j'...
# Downloaded: 4O0J
# Downloading PDB structure '4b34'...
# Downloaded: 4B34
# Downloading PDB structure '5kgs'...
# Downloaded: 5KGS
# Downloading PDB structure '3t0w'...
# Downloaded: 3T0W
# Downloading PDB structure '2pze'...
# Downloaded: 2PZE
# Downloading PDB structure '1njj'...
# Downloaded: 1NJJ
# Downloading PDB structure '5l91'...
# Downloaded: 5L91
# Downloading PDB structure '5lji'...
# Downloaded: 5LJI
# Downloading PDB structure '5glz'...
# Downloaded: 5GLZ
# Downloading PDB structure '3fuh'...
# Downloaded: 3FUH
# Downloading PDB structure '4xtz'...
# Downloaded: 4XTZ
# Downloading PDB structure '3e7f'...
# Downloaded: 3E7F
# Downloading PDB structure '2cgr'...
# Downloaded: 2CGR
# Downloading PDB structure '3mnp'...
# Downloaded: 3MNP
# Downloading PDB structure '2pdi'...
# Downloaded: 2PDI
# Downloading PDB structure '1wcb'...
# Downloaded: 1WCB
# Downloading PDB structure '3ljo'...
# Downloaded: 3LJO
# Downloading PDB structure '3of2'...
# Downloaded: 3OF2
# Downloading PDB structure '4i9o'...
# Downloaded: 4I9O
# Downloading PDB structure '5doh'...
# Downloaded: 5DOH
# Downloading PDB structure '2f2u'...
# Downloaded: 2F2U
# Downloading PDB structure '3bxg'...
# Downloaded: 3BXG
# Downloading PDB structure '4mhw'...
# Downloaded: 4MHW
# Downloading PDB structure '186l'...
# Downloaded: 186L
# Downloading PDB structure '3sie'...
# Downloaded: 3SIE
# Downloading PDB structure '3ekq'...
# Downloaded: 3EKQ
# Downloading PDB structure '3bpx'...
# Downloaded: 3BPX
# Downloading PDB structure '2a4w'...
# Downloaded: 2A4W
# Downloading PDB structure '1dhf'...
# Downloaded: 1DHF
# Downloading PDB structure '3aj6'...
# Downloaded: 3AJ6
# Downloading PDB structure '1bf3'...
# Downloaded: 1BF3
# Downloading PDB structure '1sw1'...
# Downloaded: 1SW1
# Downloading PDB structure '5mpz'...
# Downloaded: 5MPZ
# Downloading PDB structure '3kgu'...
# Downloaded: 3KGU
# Downloading PDB structure '4pow'...
# Downloaded: 4POW
# Downloading PDB structure '5cbr'...
# Downloaded: 5CBR
# Downloading PDB structure '1jqv'...
# Downloaded: 1JQV
# Downloading PDB structure '4avj'...
# Downloaded: 4AVJ
# Downloading PDB structure '3mct'...
# Downloaded: 3MCT
# Downloading PDB structure '4d8z'...
# Downloaded: 4D8Z
# Downloading PDB structure '1t63'...
# Downloaded: 1T63
# Downloading PDB structure '2y34'...
# Downloaded: 2Y34
# Downloading PDB structure '3feg'...
# Downloaded: 3FEG
# Downloading PDB structure '5ad3'...
# Downloaded: 5AD3
# Downloading PDB structure '4zvl'...
# Downloaded: 4ZVL
# Downloading PDB structure '4xqa'...
# Downloaded: 4XQA
# Downloading PDB structure '1ru2'...
# Downloaded: 1RU2
# Downloading PDB structure '5tbe'...
# Downloaded: 5TBE
# Downloading PDB structure '4cx4'...
# Downloaded: 4CX4
# Downloading PDB structure '5bvb'...
# Downloaded: 5BVB
# Downloading PDB structure '3gm0'...
# Downloaded: 3GM0
# Downloading PDB structure '3mhl'...
# Downloaded: 3MHL
# Downloading PDB structure '5ji8'...
# Downloaded: 5JI8
# Downloading PDB structure '1kmy'...
# Downloaded: 1KMY
# Downloading PDB structure '4klv'...
# Downloaded: 4KLV
# Downloading PDB structure '3ozu'...
# Downloaded: 3OZU
# Downloading PDB structure '1kxm'...
# Downloaded: 1KXM
# Downloading PDB structure '4bb9'...
# Downloaded: 4BB9
# Downloading PDB structure '3ttn'...
# Downloaded: 3TTN
# Downloading PDB structure '5fng'...
# Downloaded: 5FNG
# Downloading PDB structure '4wyd'...
# Downloaded: 4WYD
# Downloading PDB structure '3r7o'...
# Downloaded: 3R7O
# Downloading PDB structure '4oag'...
# Downloaded: 4OAG
# Downloading PDB structure '2g78'...
# Downloaded: 2G78
# Downloading PDB structure '3e64'...
# Downloaded: 3E64
# Downloading PDB structure '2qft'...
# Downloaded: 2QFT
# Downloading PDB structure '9abp'...
# Downloaded: 9ABP
# Downloading PDB structure '4cjn'...
# Downloaded: 4CJN
# Downloading PDB structure '5m04'...
# Downloaded: 5M04
# Downloading PDB structure '220l'...
# Downloaded: 220L
# Downloading PDB structure '1hmr'...
# Downloaded: 1HMR
# Downloading PDB structure '5vw2'...
# Downloaded: 5VW2
# Downloading PDB structure '4ez7'...
# Downloaded: 4EZ7
# Downloading PDB structure '1yid'...
# Downloaded: 1YID
# Downloading PDB structure '3o8p'...
# Downloaded: 3O8P
# Downloading PDB structure '2gzl'...
# Downloaded: 2GZL
# Downloading PDB structure '4loq'...
# Downloaded: 4LOQ
# Downloading PDB structure '4zme'...
# Downloaded: 4ZME
# Downloading PDB structure '3hdy'...
# Downloaded: 3HDY
# Downloading PDB structure '1hq5'...
# Downloaded: 1HQ5
# Downloading PDB structure '4bva'...
# Downloaded: 4BVA
# Downloading PDB structure '1bwn'...
# Downloaded: 1BWN
# Downloading PDB structure '2pqc'...
# Downloaded: 2PQC
# Downloading PDB structure '4k13'...
# Downloaded: 4K13
# Downloading PDB structure '4nvp'...
# Downloaded: 4NVP
# Downloading PDB structure '2pdw'...
# Downloaded: 2PDW
# Downloading PDB structure '4bkj'...
# Downloaded: 4BKJ
# Downloading PDB structure '3gk2'...
# Downloaded: 3GK2
# Downloading PDB structure '2w92'...
# Downloaded: 2W92
# Downloading PDB structure '3dgo'...
# Downloaded: 3DGO
# Downloading PDB structure '3gy6'...
# Downloaded: 3GY6
# Downloading PDB structure '5lpl'...
# Downloaded: 5LPL
# Downloading PDB structure '3fzy'...
# Downloaded: 3FZY
# Downloading PDB structure '4qzu'...
# Downloaded: 4QZU
# Downloading PDB structure '4i91'...
# Downloaded: 4I91
# Downloading PDB structure '4c4r'...
# Downloaded: 4C4R
# Downloading PDB structure '3ppr'...
# Downloaded: 3PPR
# Downloading PDB structure '5kcz'...
# Downloaded: 5KCZ
# Downloading PDB structure '3dkg'...
# Downloaded: 3DKG
# Downloading PDB structure '1c6z'...
# Downloaded: 1C6Z
# Downloading PDB structure '2q8h'...
# Downloaded: 2Q8H
# Downloading PDB structure '2wsv'...
# Downloaded: 2WSV
# Downloading PDB structure '1qpb'...
# Downloaded: 1QPB
# Downloading PDB structure '2aqb'...
# Downloaded: 2AQB
# Downloading PDB structure '1b55'...
# Downloaded: 1B55
# Downloading PDB structure '3r24'...
# Downloaded: 3R24
# Downloading PDB structure '3sw7'...
# Downloaded: 3SW7
# Downloading PDB structure '1lin'...
# Downloaded: 1LIN
# Downloading PDB structure '5igp'...
# Downloaded: 5IGP
# Downloading PDB structure '1x70'...
# Downloaded: 1X70
# Downloading PDB structure '4av4'...
# Downloaded: 4AV4
# Downloading PDB structure '5dpv'...
# Downloaded: 5DPV
# Downloading PDB structure '1q7b'...
# Downloaded: 1Q7B
# Downloading PDB structure '5ka1'...
# Downloaded: 5KA1
# Downloading PDB structure '5aqy'...
# Downloaded: 5AQY
# Downloading PDB structure '1n4h'...
# Downloaded: 1N4H
# Downloading PDB structure '2o9a'...
# Downloaded: 2O9A
# Downloading PDB structure '4h85'...
# Downloaded: 4H85
# Downloading PDB structure '1qy1'...
# Downloaded: 1QY1
# Downloading PDB structure '3gni'...
# Downloaded: 3GNI
# Downloading PDB structure '2vzm'...
# Downloaded: 2VZM
# Downloading PDB structure '1ogx'...
# Downloaded: 1OGX
# Downloading PDB structure '4k7o'...
# Downloaded: 4K7O
# Downloading PDB structure '3ht6'...
# Downloaded: 3HT6
# Downloading PDB structure '5mod'...
# Downloaded: 5MOD
# Downloading PDB structure '4m5l'...
# Downloaded: 4M5L
# Downloading PDB structure '1exa'...
# Downloaded: 1EXA
# Downloading PDB structure '3cuk'...
# Downloaded: 3CUK
# Downloading PDB structure '5g61'...
# Downloaded: 5G61
# Downloading PDB structure '4bjx'...
# Downloaded: 4BJX
# Downloading PDB structure '4zzd'...
# Downloaded: 4ZZD
# Downloading PDB structure '4o2a'...
# Downloaded: 4O2A
# Downloading PDB structure '1a4r'...
# Downloaded: 1A4R
# Downloading PDB structure '2yld'...
# Downloaded: 2YLD
# Downloading PDB structure '5lvn'...
# Downloaded: 5LVN
# Downloading PDB structure '5vjg'...
# Downloaded: 5VJG
# Downloading PDB structure '3aqa'...
# Downloaded: 3AQA
# Downloading PDB structure '2gz2'...
# Downloaded: 2GZ2
# Downloading PDB structure '5mwj'...
# Downloaded: 5MWJ
# Downloading PDB structure '4rra'...
# Downloaded: 4RRA
# Downloading PDB structure '3zll'...
# Downloaded: 3ZLL
# Downloading PDB structure '2xxt'...
# Downloaded: 2XXT
# Downloading PDB structure '5vc4'...
# Downloaded: 5VC4
# Downloading PDB structure '4pul'...
# Downloaded: 4PUL
# Downloading PDB structure '5flr'...
# Downloaded: 5FLR
# Downloading PDB structure '3m6p'...
# Downloaded: 3M6P
# Downloading PDB structure '3smr'...
# Downloaded: 3SMR
# Downloading PDB structure '1mep'...
# Downloaded: 1MEP
# Downloading PDB structure '1el9'...
# Downloaded: 1EL9
# Downloading PDB structure '4azb'...
# Downloaded: 4AZB
# Downloading PDB structure '5dus'...
# Downloaded: 5DUS
# Downloading PDB structure '2y6o'...
# Downloaded: 2Y6O
# Downloading PDB structure '4uwd'...
# Downloaded: 4UWD
# Downloading PDB structure '3gcs'...
# Downloaded: 3GCS
# Downloading PDB structure '4fak'...
# Downloaded: 4FAK
# Downloading PDB structure '3l68'...
# Downloaded: 3L68
# Downloading PDB structure '3lxk'...
# Downloaded: 3LXK
# Downloading PDB structure '1wdr'...
# Downloaded: 1WDR
# Downloading PDB structure '5lb6'...
# Downloaded: 5LB6
# Downloading PDB structure '5l8p'...
# Downloaded: 5L8P
# Downloading PDB structure '1azl'...
# Downloaded: 1AZL
# Downloading PDB structure '5fnt'...
# Downloaded: 5FNT
# Downloading PDB structure '2o5z'...
# Downloaded: 2O5Z
# Downloading PDB structure '3hs5'...
# Downloaded: 3HS5
# Downloading PDB structure '2gqg'...
# Downloaded: 2GQG
# Downloading PDB structure '1wpg'...
# Downloaded: 1WPG
# Downloading PDB structure '3uj9'...
# Downloaded: 3UJ9
# Downloading PDB structure '3s43'...
# Downloaded: 3S43
# Downloading PDB structure '3vsp'...
# Downloaded: 3VSP
# Downloading PDB structure '4uhi'...
# Downloaded: 4UHI
# Downloading PDB structure '3s74'...
# Downloaded: 3S74
# Downloading PDB structure '3ad8'...
# Downloaded: 3AD8
# Downloading PDB structure '4axd'...
# Downloaded: 4AXD
# Downloading PDB structure '3nht'...
# Downloaded: 3NHT
# Downloading PDB structure '1utm'...
# Downloaded: 1UTM
# Downloading PDB structure '2vcb'...
# Downloaded: 2VCB
# Downloading PDB structure '4gu6'...
# Downloaded: 4GU6
# Downloading PDB structure '5vb5'...
# Downloaded: 5VB5
# Downloading PDB structure '4cwv'...
# Downloaded: 4CWV
# Downloading PDB structure '4x8o'...
# Downloaded: 4X8O
# Downloading PDB structure '3jvs'...
# Downloaded: 3JVS
# Downloading PDB structure '1lnm'...
# Downloaded: 1LNM
# Downloading PDB structure '4ktk'...
# Downloaded: 4KTK
# Downloading PDB structure '3zy5'...
# Downloaded: 3ZY5
# Downloading PDB structure '4f1y'...
# Downloaded: 4F1Y
# Downloading PDB structure '5vcy'...
# Downloaded: 5VCY
# Downloading PDB structure '4zei'...
# Downloaded: 4ZEI
# Downloading PDB structure '5gzd'...
# Downloaded: 5GZD
# Downloading PDB structure '5ljd'...
# Downloaded: 5LJD
# Downloading PDB structure '3hgm'...
# Downloaded: 3HGM
# Downloading PDB structure '3fue'...
# Downloaded: 3FUE
# Downloading PDB structure '4xtw'...
# Downloaded: 4XTW
# Downloading PDB structure '2yme'...
# Downloaded: 2YME
# Downloading PDB structure '3hzf'...
# Downloaded: 3HZF
# Downloading PDB structure '2c3i'...
# Downloaded: 2C3I
# Downloading PDB structure '1jrb'...
# Downloaded: 1JRB
# Downloading PDB structure '1cnw'...
# Downloaded: 1CNW
# Downloading PDB structure '4ahu'...
# Downloaded: 4AHU
# Downloading PDB structure '4b7p'...
# Downloaded: 4B7P
# Downloading PDB structure '4yxi'...
# Downloaded: 4YXI
# Downloading PDB structure '3rj9'...
# Downloaded: 3RJ9
# Downloading PDB structure '3ivx'...
# Downloaded: 3IVX
# Downloading PDB structure '2pk5'...
# Downloaded: 2PK5
# Downloading PDB structure '3i33'...
# Downloaded: 3I33
# Downloading PDB structure '1vc9'...
# Downloaded: 1VC9
# Downloading PDB structure '1uod'...
# Downloaded: 1UOD
# Downloading PDB structure '1cmp'...
# Downloaded: 1CMP
# Downloading PDB structure '3qxh'...
# Downloaded: 3QXH
# Downloading PDB structure '1opj'...
# Downloaded: 1OPJ
# Downloading PDB structure '4g44'...
# Downloaded: 4G44
# Downloading PDB structure '4ug8'...
# Downloaded: 4UG8
# Downloading PDB structure '5e58'...
# Downloaded: 5E58
# Downloading PDB structure '3rhr'...
# Downloaded: 3RHR
# Downloading PDB structure '4qpl'...
# Downloaded: 4QPL
# Downloading PDB structure '2cbz'...
# Downloaded: 2CBZ
# Downloading PDB structure '3r35'...
# Downloaded: 3R35
# Downloading PDB structure '3lk0'...
# Downloaded: 3LK0
# Downloading PDB structure '5hf9'...
# Downloaded: 5HF9
# Downloading PDB structure '5c3r'...
# Downloaded: 5C3R
# Downloading PDB structure '2vo4'...
# Downloaded: 2VO4
# Downloading PDB structure '3i9g'...
# Downloaded: 3I9G
# Downloading PDB structure '5eps'...
# Downloaded: 5EPS
# Downloading PDB structure '2cib'...
# Downloaded: 2CIB
# Downloading PDB structure '4u7g'...
# Downloaded: 4U7G
# Downloading PDB structure '4xzj'...
# Downloaded: 4XZJ
# Downloading PDB structure '2jgs'...
# Downloaded: 2JGS
# Downloading PDB structure '4u0w'...
# Downloaded: 4U0W
# Downloading PDB structure '4rp9'...
# Downloaded: 4RP9
# Downloading PDB structure '2pev'...
# Downloaded: 2PEV
# Downloading PDB structure '3aru'...
# Downloaded: 3ARU
# Downloading PDB structure '1ag9'...
# Downloaded: 1AG9
# Downloading PDB structure '3e6y'...
# Downloaded: 3E6Y
# Downloading PDB structure '5ibf'...
# Downloaded: 5IBF
# Downloading PDB structure '3dsz'...
# Downloaded: 3DSZ
# Downloading PDB structure '4qjw'...
# Downloaded: 4QJW
# Downloading PDB structure '4jv6'...
# Downloaded: 4JV6
# Downloading PDB structure '3ovn'...
# Downloaded: 3OVN
# Downloading PDB structure '5h1v'...
# Downloaded: 5H1V
# Downloading PDB structure '4c1d'...
# Downloaded: 4C1D
# Downloading PDB structure '5v13'...
# Downloaded: 5V13
# Downloading PDB structure '5b5f'...
# Downloaded: 5B5F
# Downloading PDB structure '3fk7'...
# Downloaded: 3FK7
# Downloading PDB structure '3iod'...
# Downloaded: 3IOD
# Downloading PDB structure '4der'...
# Downloaded: 4DER
# Downloading PDB structure '3a6r'...
# Downloaded: 3A6R
# Downloading PDB structure '1mpw'...
# Downloaded: 1MPW
# Downloading PDB structure '5e3d'...
# Downloaded: 5E3D
# Downloading PDB structure '1x8r'...
# Downloaded: 1X8R
# Downloading PDB structure '3gus'...
# Downloaded: 3GUS
# Downloading PDB structure '1ba0'...
# Downloaded: 1BA0
# Downloading PDB structure '4y95'...
# Downloaded: 4Y95
# Downloading PDB structure '3g08'...
# Downloaded: 3G08
# Downloading PDB structure '2h2j'...
# Downloaded: 2H2J
# Downloading PDB structure '2ha2'...
# Downloaded: 2HA2
# ...
# Downloaded: 4D81
# Downloading PDB structure '184l'...
# Downloaded: 184L
# Downloading PDB structure '1odj'...
# Downloaded: 1ODJ
# Downloading PDB structure '3d1y'...
# Downloaded: 3D1Y
# Downloading PDB structure '4ih7'...
# Downloaded: 4IH7
# Downloading PDB structure '4np9'...
# Downloaded: 4NP9
# Downloading PDB structure '5nk3'...
# Downloaded: 5NK3
# Downloading PDB structure '2h4n'...
# Downloaded: 2H4N
# Downloading PDB structure '2gce'...
# Downloaded: 2GCE
# Downloading PDB structure '3ijg'...
# Downloaded: 3IJG
# Downloading PDB structure '4due'...
# Downloaded: 4DUE
# Downloading PDB structure '5jal'...
# Downloaded: 5JAL
# Downloading PDB structure '3tsk'...
# Downloaded: 3TSK
# Downloading PDB structure '4aia'...
# Downloaded: 4AIA
# Downloading PDB structure '3fzl'...
# Downloaded: 3FZL
# Downloading PDB structure '1os5'...
# Downloaded: 1OS5
# Downloading PDB structure '4ibc'...
# Downloaded: 4IBC
# Downloading PDB structure '5n18'...
# Downloaded: 5N18
# Downloading PDB structure '4tpw'...
# Downloaded: 4TPW
# Downloading PDB structure '3td4'...
# Downloaded: 3TD4
# Downloading PDB structure '3f78'...
# Downloaded: 3F78
# Downloading PDB structure '5ioz'...
# Downloaded: 5IOZ
# Downloading PDB structure '3m94'...
# Downloaded: 3M94
# Downloading PDB structure '4lht'...
# Downloaded: 4LHT
# Downloading PDB structure '3uod'...
# Downloaded: 3UOD
# Downloading PDB structure '2jjo'...
# Downloaded: 2JJO
# Downloading PDB structure '2aeb'...
# Downloaded: 2AEB
# Downloading PDB structure '4ur9'...
# Downloaded: 4UR9
# Downloading PDB structure '4p5z'...
# Downloaded: 4P5Z
# Downloading PDB structure '3te5'...
# Downloaded: 3TE5
# Downloading PDB structure '2v7a'...
# Downloaded: 2V7A
# Downloading PDB structure '4kow'...
# Downloaded: 4KOW
# Downloading PDB structure '1luq'...
# Downloaded: 1LUQ
# Downloading PDB structure '2rfy'...
# Downloaded: 2RFY
# Downloading PDB structure '3b4y'...
# Downloaded: 3B4Y
# Downloading PDB structure '2xv1'...
# Downloaded: 2XV1
# Downloading PDB structure '1gni'...
# Downloaded: 1GNI
# Downloading PDB structure '5fb7'...
# Downloaded: 5FB7
# Downloading PDB structure '2cbo'...
# Downloaded: 2CBO
# Downloading PDB structure '1mk5'...
# Downloaded: 1MK5
# Downloading PDB structure '4zhf'...
# Downloaded: 4ZHF
# Downloading PDB structure '3pyy'...
# Downloaded: 3PYY
# Downloading PDB structure '2anz'...
# Downloaded: 2ANZ
# Downloading PDB structure '1f5f'...
# Downloaded: 1F5F
# Downloading PDB structure '3kx3'...
# Downloaded: 3KX3
# Downloading PDB structure '4jfl'...
# Downloaded: 4JFL
# Downloading PDB structure '2ao6'...
# Downloaded: 2AO6
# Downloading PDB structure '3ikf'...
# Downloaded: 3IKF
# Downloading PDB structure '3ekw'...
# Downloaded: 3EKW
# Downloading PDB structure '3qse'...
# Downloaded: 3QSE
# Downloading PDB structure '1e8w'...
# Downloaded: 1E8W
# Downloading PDB structure '4ymh'...
# Downloaded: 4YMH
# Downloading PDB structure '4z1j'...
# Downloaded: 4Z1J
# Downloading PDB structure '5ln8'...
# Downloaded: 5LN8
# Downloading PDB structure '4no4'...
# Downloaded: 4NO4
# Downloading PDB structure '5meh'...
# Downloaded: 5MEH
# Downloading PDB structure '4fxq'...
# Downloaded: 4FXQ
# Downloading PDB structure '1li6'...
# Downloaded: 1LI6
# Downloading PDB structure '2g5u'...
# Downloaded: 2G5U
# Downloading PDB structure '3d76'...
# Downloaded: 3D76
# Downloading PDB structure '4ad6'...
# Downloaded: 4AD6
# Downloading PDB structure '4rr9'...
# Downloaded: 4RR9
# Downloading PDB structure '1m6p'...
# Downloaded: 1M6P
# Downloading PDB structure '4l40'...
# Downloaded: 4L40
# Downloading PDB structure '4q07'...
# Downloaded: 4Q07
# Downloading PDB structure '5ab7'...
# Downloaded: 5AB7
# Downloading PDB structure '4c0c'...
# Downloaded: 4C0C
# Downloading PDB structure '1tco'...
# Downloaded: 1TCO
# Downloading PDB structure '5goe'...
# Downloaded: 5GOE
# Downloading PDB structure '1zds'...
# Downloaded: 1ZDS
# Downloading PDB structure '4f1l'...
# Downloaded: 4F1L
# Downloading PDB structure '2uxu'...
# Downloaded: 2UXU
# Downloading PDB structure '3fup'...
# Downloaded: 3FUP
# Downloading PDB structure '3le8'...
# Downloaded: 3LE8
# Downloading PDB structure '4bcs'...
# Downloaded: 4BCS
# Downloading PDB structure '3el9'...
# Downloaded: 3EL9
# Downloading PDB structure '1m5w'...
# Downloaded: 1M5W
# Downloading PDB structure '4l77'...
# Downloaded: 4L77
# Downloading PDB structure '5kqx'...
# Downloaded: 5KQX
# Downloading PDB structure '4mr4'...
# Downloaded: 4MR4
# Downloading PDB structure '3gk4'...
# Downloaded: 3GK4
# Downloading PDB structure '2pdq'...
# Downloaded: 2PDQ
# Downloading PDB structure '3qug'...
# Downloaded: 3QUG
# Downloading PDB structure '3ao5'...
# Downloaded: 3AO5
# Downloading PDB structure '3gws'...
# Downloaded: 3GWS
# Downloading PDB structure '5w10'...
# Downloaded: 5W10
# Downloading PDB structure '2bmv'...
# Downloaded: 2BMV
# Downloading PDB structure '1mrw'...
# Downloaded: 1MRW
# Downloading PDB structure '4n9i'...
# Downloaded: 4N9I
# Downloading PDB structure '4dzy'...
# Downloaded: 4DZY
# Downloading PDB structure '1xa5'...
# Downloaded: 1XA5
# Downloading PDB structure '4j36'...
# Downloaded: 4J36
# Downloading PDB structure '3nuj'...
# Downloaded: 3NUJ
# Downloading PDB structure '1qk3'...
# Downloaded: 1QK3
# Downloading PDB structure '1hmt'...
# Downloaded: 1HMT
# Downloading PDB structure '3lzx'...
# Downloaded: 3LZX
# Downloading PDB structure '3lgs'...
# Downloaded: 3LGS
# Downloading PDB structure '2xdk'...
# Downloaded: 2XDK
# Downloading PDB structure '2j7g'...
# Downloaded: 2J7G
# Downloading PDB structure '2vcw'...
# Downloaded: 2VCW
# Downloading PDB structure '3p3c'...
# Downloaded: 3P3C
# Downloading PDB structure '5ka7'...
# Downloaded: 5KA7
# Downloading PDB structure '3qdd'...
# Downloaded: 3QDD
# Downloading PDB structure '3cd0'...
# Downloaded: 3CD0
# Downloading PDB structure '1jmi'...
# Downloaded: 1JMI
# Downloading PDB structure '4ugs'...
# Downloaded: 4UGS
# Downloading PDB structure '2izf'...
# Downloaded: 2IZF
# Downloading PDB structure '5l4m'...
# Downloaded: 5L4M
# Downloading PDB structure '2qwq'...
# Downloaded: 2QWQ
# Downloading PDB structure '3nrz'...
# Downloaded: 3NRZ
# Downloading PDB structure '5fbi'...
# Downloaded: 5FBI
# Downloading PDB structure '1m83'...
# Downloaded: 1M83
# Downloading PDB structure '4k7i'...
# Downloaded: 4K7I
# Downloading PDB structure '1yej'...
# Downloaded: 1YEJ
# Downloading PDB structure '5k9w'...
# Downloaded: 5K9W
# Downloading PDB structure '3r0y'...
# Downloaded: 3R0Y
# Downloading PDB structure '5mob'...
# Downloaded: 5MOB
# Downloading PDB structure '5dfc'...
# Downloaded: 5DFC
# Downloading PDB structure '2a5c'...
# Downloaded: 2A5C
# Downloading PDB structure '4gq4'...
# Downloaded: 4GQ4
# Downloading PDB structure '3kmy'...
# Downloaded: 3KMY
# Downloading PDB structure '4qzs'...
# Downloaded: 4QZS
# Downloading PDB structure '2p09'...
# Downloaded: 2P09
# Downloading PDB structure '5f3z'...
# Downloaded: 5F3Z
# Downloading PDB structure '1tog'...
# Downloaded: 1TOG
# Downloading PDB structure '5lpj'...
# Downloaded: 5LPJ
# Downloading PDB structure '4co3'...
# Downloaded: 4CO3
# Downloading PDB structure '2arc'...
# Downloaded: 2ARC
# Downloading PDB structure '3mag'...
# Downloaded: 3MAG
# Downloading PDB structure '1aj6'...
# Downloaded: 1AJ6
# Downloading PDB structure '4kne'...
# Downloaded: 4KNE
# Downloading PDB structure '1ggd'...
# Downloaded: 1GGD
# Downloading PDB structure '4eiy'...
# Downloaded: 4EIY
# Downloading PDB structure '5ers'...
# Downloaded: 5ERS
# Downloading PDB structure '2xb7'...
# Downloaded: 2XB7
# Downloading PDB structure '4nra'...
# Downloaded: 4NRA
# Downloading PDB structure '1bnt'...
# Downloaded: 1BNT
# Downloading PDB structure '5khd'...
# Downloaded: 5KHD
# Downloading PDB structure '4uin'...
# Downloaded: 4UIN
# Downloading PDB structure '3dd0'...
# Downloaded: 3DD0
# Downloading PDB structure '4rrg'...
# Downloaded: 4RRG
# Downloading PDB structure '2z93'...
# Downloaded: 2Z93
# Downloading PDB structure '4puj'...
# Downloaded: 4PUJ
# Downloading PDB structure '5flt'...
# Downloaded: 5FLT
# Downloading PDB structure '3l59'...
# Downloaded: 3L59
# Downloading PDB structure '3lfa'...
# Downloaded: 3LFA
# Downloading PDB structure '1lf9'...
# Downloaded: 1LF9
# Downloading PDB structure '3gcu'...
# Downloaded: 3GCU
# Downloading PDB structure '4hse'...
# Downloaded: 4HSE
# Downloading PDB structure '1cam'...
# Downloaded: 1CAM
# Downloading PDB structure '5aan'...
# Downloaded: 5AAN
# Downloading PDB structure '4bv9'...
# Downloaded: 4BV9
# Downloading PDB structure '5x4q'...
# Downloaded: 5X4Q
# Downloading PDB structure '4k9t'...
# Downloaded: 4K9T
# Downloading PDB structure '4dst'...
# Downloaded: 4DST
# Downloading PDB structure '4ago'...
# Downloaded: 4AGO
# Downloading PDB structure '3s54'...
# Downloaded: 3S54
# Downloading PDB structure '3nk8'...
# Downloaded: 3NK8
# Downloading PDB structure '5j5i'...
# Downloaded: 5J5I
# Downloading PDB structure '3rlp'...
# Downloaded: 3RLP
# Downloading PDB structure '3u15'...
# Downloaded: 3U15
# Downloading PDB structure '2w09'...
# Downloaded: 2W09
# Downloading PDB structure '4m5j'...
# Downloaded: 4M5J
# Downloading PDB structure '4as7'...
# Downloaded: 4AS7
# Downloading PDB structure '3rdo'...
# Downloaded: 3RDO
# Downloading PDB structure '3nu4'...
# Downloaded: 3NU4
# Downloading PDB structure '3ads'...
# Downloaded: 3ADS
# Downloading PDB structure '1gaf'...
# Downloaded: 1GAF
# Downloading PDB structure '2j79'...
# Downloaded: 2J79
# Downloading PDB structure '5etq'...
# Downloaded: 5ETQ
# Downloading PDB structure '4ajk'...
# Downloaded: 4AJK
# Downloading PDB structure '4ury'...
# Downloaded: 4URY
# Downloading PDB structure '1olx'...
# Downloaded: 1OLX
# Downloading PDB structure '2f8g'...
# Downloaded: 2F8G
# Downloading PDB structure '3oy4'...
# Downloaded: 3OY4
# Downloading PDB structure '4ugm'...
# Downloaded: 4UGM
# Downloading PDB structure '2r5a'...
# Downloaded: 2R5A
# Downloading PDB structure '2qwo'...
# Downloaded: 2QWO
# Downloading PDB structure '3m8u'...
# Downloaded: 3M8U
# Downloading PDB structure '3ndw'...
# Downloaded: 3NDW
# Downloading PDB structure '5aom'...
# Downloaded: 5AOM
# Downloading PDB structure '4duh'...
# Downloaded: 4DUH
# Downloading PDB structure '3bym'...
# Downloaded: 3BYM
# Downloading PDB structure '1yet'...
# Downloaded: 1YET
# Downloading PDB structure '2as1'...
# Downloaded: 2AS1
# Downloading PDB structure '3qri'...
# Downloaded: 3QRI
# Downloading PDB structure '3pd2'...
# Downloaded: 3PD2
# Downloading PDB structure '2vrj'...
# Downloaded: 2VRJ
# Downloading PDB structure '2p9t'...
# Downloaded: 2P9T
# Downloading PDB structure '1k74'...
# Downloaded: 1K74
# Downloading PDB structure '2uwd'...
# Downloaded: 2UWD
# Downloading PDB structure '4zij'...
# Downloaded: 4ZIJ
# Downloading PDB structure '3a20'...
# Downloaded: 3A20
# Downloading PDB structure '3pma'...
# Downloaded: 3PMA
# Downloading PDB structure '5uk8'...
# Downloaded: 5UK8
# Downloading PDB structure '4w9l'...
# Downloaded: 4W9L
# Downloading PDB structure '5kcb'...
# Downloaded: 5KCB
# Downloading PDB structure '3l1n'...
# Downloaded: 3L1N
# Downloading PDB structure '1r9l'...
# Downloaded: 1R9L
# Downloading PDB structure '3hub'...
# Downloaded: 3HUB
# Downloading PDB structure '3oxx'...
# Downloaded: 3OXX
# Downloading PDB structure '1t79'...
# Downloaded: 1T79
# Downloading PDB structure '3gr6'...
# Downloaded: 3GR6
# Downloading PDB structure '4db7'...
# Downloaded: 4DB7
# Downloading PDB structure '5tco'...
# Downloaded: 5TCO
# Downloading PDB structure '1xqd'...
# Downloaded: 1XQD
# Downloading PDB structure '2f14'...
# Downloaded: 2F14
# Downloading PDB structure '4ocj'...
# Downloaded: 4OCJ
# Downloading PDB structure '4mlx'...
# Downloaded: 4MLX
# Downloading PDB structure '2a8g'...
# Downloaded: 2A8G
# Downloading PDB structure '4ef6'...
# Downloaded: 4EF6
# Downloading PDB structure '4wmz'...
# Downloaded: 4WMZ
# Downloading PDB structure '2jf4'...
# Downloaded: 2JF4
# Downloading PDB structure '1rmz'...
# Downloaded: 1RMZ
# Downloading PDB structure '5l9i'...
# Downloaded: 5L9I
# Downloading PDB structure '2ews'...
# Downloaded: 2EWS
# Downloading PDB structure '2r0d'...
# Downloaded: 2R0D
# Downloading PDB structure '5x4o'...
# Downloaded: 5X4O
# Downloading PDB structure '5fom'...
# Downloaded: 5FOM
# Downloading PDB structure '5l1v'...
# Downloaded: 5L1V
# Downloading PDB structure '1cil'...
# Downloaded: 1CIL
# Downloading PDB structure '4agq'...
# Downloaded: 4AGQ
# Downloading PDB structure '4fil'...
# Downloaded: 4FIL
# Downloading PDB structure '3ryz'...
# Downloaded: 3RYZ
# Downloading PDB structure '5gmn'...
# Downloaded: 5GMN
# Downloading PDB structure '2fov'...
# Downloaded: 2FOV
# Downloading PDB structure '5ewh'...
# Downloaded: 5EWH
# Downloading PDB structure '5t52'...
# Downloaded: 5T52
# Downloading PDB structure '2nx3'...
# Downloaded: 2NX3
# Downloading PDB structure '4nbn'...
# Downloaded: 4NBN
# Downloading PDB structure '3rdq'...
# Downloaded: 3RDQ
# Downloading PDB structure '5c7n'...
# Downloaded: 5C7N
# Downloading PDB structure '1ws5'...
# Downloaded: 1WS5
# Downloading PDB structure '5u5z'...
# Downloaded: 5U5Z
# Downloading PDB structure '2q6m'...
# Downloaded: 2Q6M
# Downloading PDB structure '4y3j'...
# Downloaded: 4Y3J
# Downloading PDB structure '5fe9'...
# Downloaded: 5FE9
# Downloading PDB structure '3e5u'...
# Downloaded: 3E5U
# Downloading PDB structure '5eto'...
# Downloaded: 5ETO
# Downloading PDB structure '3f17'...
# Downloaded: 3F17
# Downloading PDB structure '4iuo'...
# Downloaded: 4IUO
# Downloading PDB structure '3hww'...
# Downloaded: 3HWW
# Downloading PDB structure '1y5u'...
# Downloaded: 1Y5U
# Downloading PDB structure '3vw2'...
# Downloaded: 3VW2
# Downloading PDB structure '2ez7'...
# Downloaded: 2EZ7
# Downloading PDB structure '4ra1'...
# Downloaded: 4RA1
# Downloading PDB structure '2p15'...
# Downloaded: 2P15
# Downloading PDB structure '5vsc'...
# Downloaded: 5VSC
# Downloading PDB structure '4nxu'...
# Downloaded: 4NXU
# Downloading PDB structure '2wdo'...
# Downloaded: 2WDO
# Downloading PDB structure '3had'...
# Downloaded: 3HAD
# Downloading PDB structure '4dtz'...
# Downloaded: 4DTZ
# Downloading PDB structure '5t3n'...
# Downloaded: 5T3N
# Downloading PDB structure '3nee'...
# Downloaded: 3NEE
# Downloading PDB structure '3rw9'...
# Downloaded: 3RW9
# Downloading PDB structure '4c73'...
# Downloaded: 4C73
# Downloading PDB structure '5ig6'...
# Downloaded: 5IG6
# Downloading PDB structure '3kry'...
# Downloaded: 3KRY
# Downloading PDB structure '1bn4'...
# Downloaded: 1BN4
# Downloading PDB structure '3qxc'...
# Downloaded: 3QXC
# Downloading PDB structure '5ehv'...
# Downloaded: 5EHV
# Downloading PDB structure '4loi'...
# Downloaded: 4LOI
# Downloading PDB structure '2cll'...
# Downloaded: 2CLL
# Downloading PDB structure '3hqu'...
# Downloaded: 3HQU
# Downloading PDB structure '4dm8'...
# Downloaded: 4DM8
# Downloading PDB structure '4xjp'...
# Downloaded: 4XJP
# Downloading PDB structure '1dl7'...
# Downloaded: 1DL7
# Downloading PDB structure '4b32'...
# Downloaded: 4B32
# Downloading PDB structure '5d3y'...
# Downloaded: 5D3Y
# Downloading PDB structure '1y8o'...
# Downloaded: 1Y8O
# Downloading PDB structure '2ij7'...
# Downloaded: 2IJ7
# Downloading PDB structure '5evz'...
# Downloaded: 5EVZ
# Downloading PDB structure '4ipj'...
# Downloaded: 4IPJ
# Downloading PDB structure '1p1n'...
# Downloaded: 1P1N
# Downloading PDB structure '2rcb'...
# Downloaded: 2RCB
# Downloading PDB structure '4a4w'...
# Downloaded: 4A4W
# Downloading PDB structure '3hzm'...
# Downloaded: 3HZM
# Downloading PDB structure '3drc'...
# Downloaded: 3DRC
# Downloading PDB structure '5lwd'...
# Downloaded: 5LWD
# Downloading PDB structure '3fhe'...
# Downloaded: 3FHE
# Downloading PDB structure '5ai1'...
# Downloaded: 5AI1
# Downloading PDB structure '3quy'...
# Downloaded: 3QUY
# Downloading PDB structure '2aa5'...
# Downloaded: 2AA5
# Downloading PDB structure '4i7j'...
# Downloaded: 4I7J
# Downloading PDB structure '5d25'...
# Downloaded: 5D25
# Downloading PDB structure '3bvb'...
# Downloaded: 3BVB
# Downloading PDB structure '3p8e'...
# Downloaded: 3P8E
# Downloading PDB structure '2vhq'...
# Downloaded: 2VHQ
# Downloading PDB structure '4xu0'...
# Downloaded: 4XU0
# Downloading PDB structure '2nmy'...
# Downloaded: 2NMY
# Downloading PDB structure '1q8u'...
# Downloaded: 1Q8U
# Downloading PDB structure '4yux'...
# Downloaded: 4YUX
# Downloading PDB structure '4rsk'...
# Downloaded: 4RSK
# Downloading PDB structure '2q63'...
# Downloaded: 2Q63
# Downloading PDB structure '4ddk'...
# Downloaded: 4DDK
# Downloading PDB structure '5ia4'...
# Downloaded: 5IA4
# Downloading PDB structure '3efs'...
# Downloaded: 3EFS
# Downloading PDB structure '4er0'...
# Downloaded: 4ER0
# Downloading PDB structure '2xdu'...
# Downloaded: 2XDU
# Downloading PDB structure '2d0e'...
# Downloaded: 2D0E
# Downloading PDB structure '2vci'...
# Downloaded: 2VCI
# Downloading PDB structure '4fvr'...
# Downloaded: 4FVR

# %% [markdown]
# Extract features based on the binding pocket.

# %%
from Bio.PDB import PDBParser, NeighborSearch, Selection, is_aa 
import pandas as pd 
import subprocess
from Bio.PDB.MMCIF2Dict import MMCIF2Dict
import os
import numpy as np
import torch
import torch.nn as nn
import os
import numpy as np
from Bio.PDB.DSSP import DSSP

# Set the working directory
os.chdir('/Users/javierherranzdelcerro/Desktop/PYT_SBI/SBPYT_project')

class ProteinFeatures:
    
    def __init__(self, pdb_file, pocket_pdb_file=None):
        self.dssp_executable = '/opt/homebrew/bin/mkdssp' 
        self.pocket_pdb_file = pocket_pdb_file
        self.pdb_file = pdb_file
        self.parser = PDBParser(QUIET=True)
        self.amino_acids = ['ALA', 'CYS', 'ASP', 'GLU', 'PHE', 'GLY', 'HIS', 'ILE', 'LYS', 'LEU', 
                            'MET', 'ASN', 'PRO', 'GLN', 'ARG', 'SER', 'THR', 'VAL', 'TRP', 'TYR']
        self.secondary_structure_codes = ['H', 'B', 'E', 'G', 'I', 'T', 'S', ' ', '.']
        self.pocket_residues = self.load_pocket_residues()
        torch.manual_seed(42)  # Set a fixed seed for random number generation
        self.structure = self.parser.get_structure('protein', self.pdb_file)

    
    
    def extract_sequence(self):
        parser = PDBParser()
        structure = parser.get_structure('protein', self.pdb_file)
        model = structure[0]  # Assuming single model
        chain = model['A']  # Assuming chain A, change as needed
        residues = chain.get_residues()

        aminoacid_counts = {}
        total_residues = 0

        for residue in residues:
            if residue.get_id()[0] == ' ':
                aminoacid = residue.get_resname()
                aminoacid_counts[aminoacid] = aminoacid_counts.get(aminoacid, 0) + 1
                total_residues += 1

        aminoacid_frequencies = {aminoacid: count / total_residues for aminoacid, count in aminoacid_counts.items()}

        return aminoacid_frequencies
    
    def calculate_total_contact(self):
        """Calculate the total contact for each residue based on a distance threshold."""
        atom_list = Selection.unfold_entities(self.structure, 'A')  # Use self.structure
        ns = NeighborSearch(atom_list)
        total_contact_dict = {}

        for chain in self.structure.get_chains():  # Use self.structure
            for residue in chain:
                if not is_aa(residue, standard=True):  # Skip non-amino acid entities, ensure to import is_aa
                    continue
                residue_key = (chain.id, residue.id)
                contacts = ns.search(residue.center_of_mass(), 5.0, level='R')  # Search within 5Å radius
                total_contact_dict[residue_key] = len(contacts) - 1  # Subtract 1 to exclude the residue itself

        return total_contact_dict


    
    def extract_secondary_structure(self):
        parser = PDBParser(QUIET=True)
        structure = parser.get_structure('protein', self.pdb_file)
        model = structure[0]

        # Generate DSSP data using Biopython's DSSP wrapper
        dssp = DSSP(model, self.pdb_file, dssp=self.dssp_executable)

        # Structured data to store the features
        structured_results = {}

        # Iterate over DSSP output to populate structured_results
        for key in dssp.keys():
            res_id = (key[0], key[1][1])  # Chain ID and residue number (ignoring insertion code for simplicity)
            _, _, ss, access, phi, psi = dssp[key][:6]  # Extract the necessary data
            structured_results[res_id] = {
                'secondary_structure': ss,
                'solvent_accessibility': access,
                'phi': phi,
                'psi': psi
            }

        return structured_results
    
    def load_pocket_residues(self):
        pocket_residues_set = set()
        if self.pocket_pdb_file:
            with open(self.pocket_pdb_file, 'r') as file:
                for line in file:
                    if line.startswith('ATOM'):
                        chain = line[21]
                        residue = line[22:26].strip()
                        pocket_residues_set.add((chain, residue))
        return pocket_residues_set
    
    def extract_features(self):
        structure = self.parser.get_structure('protein', self.pdb_file)
        model = structure[0]  # Asumiendo un único modelo para simplificar
        # Inicializar listas para mantener las características extraídas
        dssp_data = self.extract_secondary_structure()
        all_features = []
        for chain in model.get_chains():
            for residue in chain.get_residues():
                if residue.get_id()[0] == ' ':  # Solo residuos estándar
                    residue_id = residue.get_id()
                    pdb_id = self.pdb_file.split('/')[-1].split('.')[0]
                    residue_name = residue.get_resname()
                    secondary_structure = dssp_data.get((chain.id, residue_id[1]), {}).get('secondary_structure', ' ')
                    solvent_accessibility = dssp_data.get((chain.id, residue_id[1]), {}).get('solvent_accessibility', ' ')
                    psi_angle = dssp_data.get((chain.id, residue_id[1]), {}).get('psi', np.nan)
                    phi_angle = dssp_data.get((chain.id, residue_id[1]), {}).get('phi', np.nan)
                    In_pocket = int((chain.id, str(residue_id[1])) in self.pocket_residues)
                    total_contact = self.calculate_total_contact().get((chain.id, residue_id[1]), 0)
        
                    feature_dict = {
                        'PDB_ID': pdb_id,
                        'Chain': chain.id,
                        'Residue_ID': residue_id[1],
                        'Residue_Name': residue_name,
                        'In_Pocket': In_pocket,
                        'Secondary_structure': secondary_structure,
                        'Solvent_accesibility': solvent_accessibility,
                        'Psi_angle': psi_angle,
                        'Phi_angle': phi_angle,
                        'Total_contact': total_contact,
                    }
                    
                    all_features.append(feature_dict)
                    
        return all_features


pdb_file = '/Users/javierherranzdelcerro/Desktop/PYT_SBI/SBPYT_project/raw_pdb/pdb5u5x.pdb'
pocket_pdb_file = '/Users/javierherranzdelcerro/Desktop/PYT_SBI/SBPYT_project/dataset/pocket_pdb/5u5x_pocket.pdb'
pf = ProteinFeatures(pdb_file, pocket_pdb_file)
features = pf.extract_features()
print(features)
# Out:
# [{'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 4, 'Residue_Name': 'LEU', 'In_Pocket': 1, 'Secondary_structure': '-', 'Solvent_accesibility': 0.8292682926829268, 'Psi_angle': 116.5, 'Phi_angle': 360.0, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 5, 'Residue_Name': 'VAL', 'In_Pocket': 0, 'Secondary_structure': '-', 'Solvent_accesibility': 0.7253521126760564, 'Psi_angle': 127.6, 'Phi_angle': -115.7, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 6, 'Residue_Name': 'HIS', 'In_Pocket': 1, 'Secondary_structure': 'E', 'Solvent_accesibility': 0.19021739130434784, 'Psi_angle': 106.3, 'Phi_angle': -116.0, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 7, 'Residue_Name': 'VAL', 'In_Pocket': 0, 'Secondary_structure': 'E', 'Solvent_accesibility': 0.49295774647887325, 'Psi_angle': 127.5, 'Phi_angle': -93.9, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 8, 'Residue_Name': 'ALA', 'In_Pocket': 0, 'Secondary_structure': '-', 'Solvent_accesibility': 0.09433962264150944, 'Psi_angle': 134.8, 'Phi_angle': -63.0, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 9, 'Residue_Name': 'SER', 'In_Pocket': 0, 'Secondary_structure': '-', 'Solvent_accesibility': 0.5769230769230769, 'Psi_angle': 110.2, 'Phi_angle': -136.6, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 10, 'Residue_Name': 'VAL', 'In_Pocket': 0, 'Secondary_structure': 'P', 'Solvent_accesibility': 0.3732394366197183, 'Psi_angle': 129.5, 'Phi_angle': -60.5, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 11, 'Residue_Name': 'GLU', 'In_Pocket': 0, 'Secondary_structure': 'P', 'Solvent_accesibility': 0.10309278350515463, 'Psi_angle': 132.4, 'Phi_angle': -50.6, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 12, 'Residue_Name': 'LYS', 'In_Pocket': 0, 'Secondary_structure': 'T', 'Solvent_accesibility': 0.9170731707317074, 'Psi_angle': 120.3, 'Phi_angle': -53.5, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 13, 'Residue_Name': 'GLY', 'In_Pocket': 0, 'Secondary_structure': 'T', 'Solvent_accesibility': 0.8571428571428571, 'Psi_angle': 0.7, 'Phi_angle': 78.6, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 14, 'Residue_Name': 'ARG', 'In_Pocket': 0, 'Secondary_structure': '-', 'Solvent_accesibility': 0.35080645161290325, 'Psi_angle': 150.9, 'Phi_angle': -85.6, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 15, 'Residue_Name': 'SER', 'In_Pocket': 0, 'Secondary_structure': '-', 'Solvent_accesibility': 0.43846153846153846, 'Psi_angle': -173.3, 'Phi_angle': -140.8, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 16, 'Residue_Name': 'TYR', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.34684684684684686, 'Psi_angle': -46.9, 'Phi_angle': -47.7, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 17, 'Residue_Name': 'GLU', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.6030927835051546, 'Psi_angle': -34.5, 'Phi_angle': -61.9, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 18, 'Residue_Name': 'ASP', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.11042944785276074, 'Psi_angle': -44.7, 'Phi_angle': -60.9, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 19, 'Residue_Name': 'PHE', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.0, 'Psi_angle': -29.7, 'Phi_angle': -76.1, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 20, 'Residue_Name': 'GLN', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.07575757575757576, 'Psi_angle': -32.7, 'Phi_angle': -65.6, 'Total_contact': 0}, {'PDB_ID': 'pdb5u5x', 'Chain': 'A', 'Residue_ID': 21, 'Residue_Name': 'LYS', 'In_Pocket': 0, 'Secondary_structure': 'H', 'Solvent_accesibility': 0.5414634146341464, 'P ...

# %% [markdown]
# Prepare the Data

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import h5py

# Asumiendo que features_array es un array de NumPy con tus características extraídas,
# pdb_names es una lista de identificadores PDB correspondientes,
# y affinities es un array de NumPy con la afinidad de cada complejo.

# Convertir pdb_names y affinities a arrays de NumPy para un manejo de datos consistente
pdb_names_array = np.array(pdb_names)
affinities_array = np.array(affinities)

# Primero, divide los datos en conjuntos de entrenamiento + validación y de prueba
X_train_val, X_test, pdb_train_val, pdb_test, aff_train_val, aff_test = train_test_split(
    features_array, pdb_names_array, affinities_array, test_size=0.20, random_state=42)

# Luego, divide el conjunto de entrenamiento + validación en conjuntos de entrenamiento y validación separados
X_train, X_val, pdb_train, pdb_val, aff_train, aff_val = train_test_split(
    X_train_val, pdb_train_val, aff_train_val, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# Guardar en archivos HDF5
output_path = '../../dataset/'  # Modifica esto según sea necesario

with h5py.File(f'{output_path}training_set.hdf5', 'w') as f_train, \
     h5py.File(f'{output_path}validation_set.hdf5', 'w') as f_val, \
     h5py.File(f'{output_path}test_set.hdf5', 'w') as f_test:

    # Conjunto de entrenamiento
    f_train.create_dataset('features', data=X_train)
    f_train.create_dataset('pdb_ids', data=pdb_train.astype('S'))  # Convertir a bytes
    f_train.create_dataset('affinities', data=aff_train)

    # Conjunto de validación
    f_val.create_dataset('features', data=X_val)
    f_val.create_dataset('pdb_ids', data=pdb_val.astype('S'))  # Convertir a bytes
    f_val.create_dataset('affinities', data=aff_val)

    # Conjunto de prueba
    f_test.create_dataset('features', data=X_test)
    f_test.create_dataset('pdb_ids', data=pdb_test.astype('S'))  # Convertir a bytes
    f_test.create_dataset('affinities', data=aff_test)

# %% [markdown]
# Define and Train the Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import h5py
from sklearn.model_selection import train_test_split
from utils import progress_bar

# Model Definition
class BindingPocketCNN(nn.Module):
    def __init__(self, num_features, seq_length):
        super(BindingPocketCNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=num_features, out_channels=64, kernel_size=5, padding=2)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, padding=2)
        # Adjust the definition of fc1 according to the sequence length adjusted by the pooling layers
        self.fc1 = nn.Linear(128 * (seq_length // 4), 128)
        self.fc2 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)  # Flatten all dimensions except for the batch
        x = F.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x

# Load Data
def load_data(input_path):
    with h5py.File(f'{input_path}/training_set.hdf5', 'r') as f:
        X_train = torch.tensor(f['features'][:], dtype=torch.float)
        y_train = torch.tensor(f['affinities'][:], dtype=torch.float).view(-1, 1)
    return X_train, y_train

# Data Preparation
input_path = '../dataset'  # Adjust as necessary
X_train, y_train = load_data(input_path)
seq_length = X_train.shape[2]  # Assuming features are in dimension 2
num_features = X_train.shape[1]

# Data Splitting (assuming data are already loaded and prepared)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Model Initialization and Training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BindingPocketCNN(num_features=num_features, seq_length=seq_length).to(device)

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 100  # Adjust as necessary

for epoch in range(num_epochs):
    model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        progress_bar(i, len(train_loader), 'Loss: %.3f' % (loss.item()))
    
    # Validation step (optional, but recommended)
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, labels).item()
            progress_bar(i, len(val_loader), 'Val Loss: %.3f' % (val_loss/(i+1)))

    print(f'Epoch {epoch+1}, Train Loss: {loss.item():.4f}, Validation Loss: {val_loss/len(val_loader):.4f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 7
#       5 from torch.utils.data import DataLoader, TensorDataset
#       6 import numpy as np
# ----> 7 import h5py
#       8 from sklearn.model_selection import train_test_split
#       9 from utils import progress_bar
#
# ModuleNotFoundError: No module named 'h5py'
